# %% [markdown]
# # Build a Planning Agent for Deep Research & Structured Report Generation with LangGraph
#
# ### IMPORTANT: Be Careful this Agent will do a lot of searches so if you run it too many times you can easily exhaust your API limits for Tavily Search if you are on the free tier
#
# In this project we will be building a Planning Agent for Deep Research and Structured Report Generation in the form of Wiki-style Reports (structured with key sections and section headings)
#
#
# ![](/Users/sachinmishra/Desktop/Agents_From_Scratch/Experiments/report_generation_flow.svg)
#
#
# ### Planning Agent for Deep Research and Structured Report Generation
#
# This project focuses on building a **Planning Agent for Deep Research and Structured Report Generation**. The agent automates the process of analyzing a user-defined topic, performing web research, and generating a well-structured report. The workflow includes the following components:
#
# 1. **Report Planning**:
#    - The agent analyzes the user-provided **topic** and **default report template** to create a custom plan for the report.
#    - Sections such as **Introduction**, **Key Sections**, and **Conclusion** are defined based on the topic.
#    - A **web search tool** is used to collect information required before deciding the main sections.
#
# 2. **Parallel Execution for Research and Writing**:
#    - The agent uses **parallel execution** to efficiently perform:
#      - **Web Research**: Queries are generated for each section and executed via the web search tool to retrieve up-to-date information.
#      - **Section Writing**: The retrieved data is used to write content for each section, with the following process:
#        - The **Researcher** gathers relevant data from the web.
#        - The **Section Writer** uses the data to generate structured content for the assigned section.
#
# 3. **Formatting Completed Sections**:
#    - Once all sections are written, they are formatted to ensure consistency and adherence to the report structure.
#
# 4. **Introduction and Conclusion Writing**:
#    - After the main sections are completed and formatted:
#      - The **Introduction** and **Conclusion** are written based on the content of the remaining sections (in parallel)
#      - This process ensures that these sections align with the overall flow and insights of the report.
#
# 5. **Final Compilation**:
#    - All completed sections are compiled together to generate the **final report**.
#    - The final output is a comprehensive and structured document in the style of wiki docs.

# %% [markdown]
# The Complete Flow:
#
# START
#   │
#   ├─→ 1️⃣ PLANNING PHASE (Sequential)
#   │    ├─ Generate initial queries
#   │    ├─ Search web with those queries (Parrallel)
#   │    └─ Create section structure
#   │
#   ├─→ 2️⃣ RESEARCH & WRITING (Parallel)
#   │    ├─ Worker 1: Research Section 1 [Processing...]
#   │    ├─ Worker 2: Research Section 2 [Processing...]
#   │    └─ Worker 3: Research Section 3 [Processing...]
#   │    (All three work at the same time!)
#   │
#   ├─→ 3️⃣ FINAL SECTIONS (Sequential - uses results from step 2)
#   │    ├─ Write Introduction (now that research is done)
#   │    └─ Write Conclusion (now that research is done)
#   │
#   ├─→ 4️⃣ COMPILE (Sequential)
#   │    └─ Combine all sections into one final report
#   │
#   └─→ END (Return full article)

# %% [markdown]
# ## Install OpenAI, LangGraph and LangChain dependencies

# %%
# !pip install langchain
# !pip install langchain-openai
# !pip install langchain-community
# !pip install langgraph
# !pip install rich

# %% [markdown]
# ## Enter Open AI API Key

# %%
from getpass import getpass

GEMINI_API_KEY = getpass('Enter Gemini API Key: ')

# %%
# GROQ_API_KEY = getpass('Enter Groq API Key: ')

# %% [markdown]
# ## Enter Tavily Search API Key
#
# Get a free API key from [here](https://tavily.com/#api)

# %%
TAVILY_API_KEY = getpass('Enter Tavily Search API Key: ')

# %% [markdown]
# ## Setup Environment Variables

# %%
import os

os.environ['OPENAI_API_KEY'] = GEMINI_API_KEY
os.environ['TAVILY_API_KEY'] = TAVILY_API_KEY

# %% [markdown]
# ## Define Agent State Schema
#
# Each specific set of operations (nodes) will have their own schema as defined below. You can customize this further based on your own style of report generation

# %%
from typing_extensions import TypedDict
from pydantic import BaseModel, Field
import operator
from typing import  Annotated, List, Optional, Literal

class Section(BaseModel):
    name: str = Field(
        description="Name for a particular section of the report.",
    )
    description: str = Field(
        description="Brief overview of the main topics and concepts to be covered in this section.",
    )
    research: bool = Field(
        description="Whether to perform web search for this section of the report."
    )
    content: str = Field(
        description="The content for this section."
    )

class Sections(BaseModel):
    sections: List[Section] = Field(
        description="All the Sections of the overall report.",
    )

class SearchQuery(BaseModel):
    search_query: str = Field(None, description="Query for web search.")

class Queries(BaseModel):
    queries: List[SearchQuery] = Field(
        description="List of web search queries.",
    )

class ReportStateInput(TypedDict):
    topic: str # Report topic

class ReportStateOutput(TypedDict):
    final_report: str # Final report

class ReportState(TypedDict):
    topic: str # Report topic
    sections: list[Section] # List of report sections
    completed_sections: Annotated[list, operator.add] # Send() API
    report_sections_from_research: str # String of any completed sections from research to write final sections
    final_report: str # Final report

class SectionState(TypedDict):
    section: Section # Report section
    search_queries: list[SearchQuery] # List of search queries
    source_str: str # String of formatted source content from web search
    report_sections_from_research: str # String of any completed sections from research to write final sections
    completed_sections: list[Section] # Final key we duplicate in outer state for Send() API

class SectionOutputState(TypedDict):
    completed_sections: list[Section] # Final key we duplicate in outer state for Send() API

# %% [markdown]
# ## All the States & All the Pydantic Schemas

# %% [markdown]
# ## Utility Functions
#
# - __`run_search_queries(...)`__ : This will asynchronously run tavily search queries for specific list of queries and return back the search results. This is async so it is non blocking and can be executed in parallel.

# %%
from langchain_community.utilities.tavily_search import TavilySearchAPIWrapper
import asyncio
from dataclasses import asdict, dataclass
from typing import List, Dict, Union, Any

# just to handle objects created from LLM reponses
@dataclass
class SearchQuery:
    search_query: str

    def to_dict(self) -> Dict[str, Any]:
        return asdict(self)


tavily_search = TavilySearchAPIWrapper()


async def run_search_queries(
    search_queries: List[Union[str, SearchQuery]],
    num_results: int = 4,
    include_raw_content: bool = False
) -> List[Dict]:

    search_tasks = []

    for query in search_queries:
        # Handle both string and SearchQuery objects
        # Just in case LLM fails to generate queries as:
        # class SearchQuery(BaseModel):
        #     search_query: str
        query_str = query.search_query if isinstance(query, SearchQuery) else str(query) # text query

        try:
            # get results from tavily asynchronously (in parallel) for each search query
            search_tasks.append(
                tavily_search.raw_results_async(
                    query=query_str,
                    max_results=num_results,
                    search_depth='advanced',
                    include_answer=False,
                    include_raw_content=include_raw_content
                )
            )
        except Exception as e:
            print(f"Error creating search task for query '{query_str}': {e}")
            continue

    # Execute all searches concurrently and await results
    try:
        if not search_tasks:
            return []
        search_docs = await asyncio.gather(*search_tasks, return_exceptions=True)
        # Filter out any exceptions from the results
        valid_results = [
            doc for doc in search_docs
            if not isinstance(doc, Exception)
        ]
        return valid_results
    except Exception as e:
        print(f"Error during search queries: {e}")
        return []

# %% [markdown]
# - __`format_search_query_results(...)`__ : This will extract the context from tavily search results, make sure content is not duplicated from same urls and format it to show the Source, URL, relevant content (and optionally raw content which can be truncated based on number of tokens)

# %%
from typing import List, Dict, Union, Any

def format_search_query_results(
    search_response: Union[Dict[str, Any], List[Any]],
    max_tokens: int = 2000,
    include_raw_content: bool = False
) -> str:
    # Approximate: 1 token ≈ 4 characters for English text
    max_chars = max_tokens * 4
    
    sources_list = []

    # Handle different response formats
    # if search results is a dict
    if isinstance(search_response, dict):
        if 'results' in search_response:
            sources_list.extend(search_response['results'])
        else:
            sources_list.append(search_response)
    # if search results is a list
    elif isinstance(search_response, list):
        for response in search_response:
            if isinstance(response, dict):
                if 'results' in response:
                    sources_list.extend(response['results'])
                else:
                    sources_list.append(response)
            elif isinstance(response, list):
                sources_list.extend(response)

    if not sources_list:
        return "No search results found."

    # Deduplicate by URL and keep unique sources (website urls)
    unique_sources = {}
    for source in sources_list:
        if isinstance(source, dict) and 'url' in source:
            if source['url'] not in unique_sources:
                unique_sources[source['url']] = source

    # Format output
    formatted_text = "Content from web search:\n\n"
    for i, source in enumerate(unique_sources.values(), 1):
        formatted_text += f"Source {source.get('title', 'Untitled')}:\n===\n"
        formatted_text += f"URL: {source['url']}\n===\n"
        formatted_text += f"Most relevant content from source: {source.get('content', 'No content available')}\n===\n"

        if include_raw_content:
            raw_content = source.get("raw_content", "")
            if raw_content:
                # Simple character-based truncation
                truncated_content = raw_content[:max_chars]
                formatted_text += f"Raw Content: {truncated_content}\n\n"

    return formatted_text.strip()

# %% [markdown]
# ## Test Sample Utility Functions

# %%
docs = await run_search_queries(['langgraph'], include_raw_content=True)
docs
# Out:
# [{'query': 'langgraph',
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'url': 'https://www.ibm.com/think/topics/langgraph',
#     'title': 'What is LangGraph?',
#     'content': '# What is LangGraph?\n\n## LangGraph overview\n\nLangGraph, created by LangChain, is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize large language models (LLMs) in a scalable and efficient manner. At its core, LangGraph uses the power of graph-based architectures to model and manage the intricate relationships between various components of an AI agent workflow. [...] Debugging: The capabilities do not end with building a graph, debugging features are included to ensure the graph is accurate and reliable. LangGraph Studio, with its cutting-edge integrated development environment (IDE), helps visualize and debug LangGraph applications.\n\n## Future developments\n\nEnhanced natural language processing (NLP): LangGraph will have more advanced NLP capabilities, allowing it to better understand natural language and provide more accurate responses.\n\nImproved machine learning: LangGraph will have improved machine learning capabilities, allowing it to learn and improve over time.\n\nSupport for new platforms: LangGraph will support new platforms, such as mobile devices and edge computing to make its technology more accessible.\n\n## Authors [...] LangGraph is also built on several key technologies, including LangChain, a Python framework for building AI applications. LangChain includes a library for building and managing LLMs. LangGraph also uses the human-in-the-loop approach. By combining these technologies with a set of APIs and tools, LangGraph provides users with a versatile platform for developing AI solutions and workflows including chatbots, state graphs and other agent-based systems.\n\nDelve deeper into the world of LangGraph by exploring its key features, benefits and use cases. By the end of this article, you will have the knowledge and resources to take the next steps with LangGraph.\n\n## Key components of LangGraph',
#     'score': 0.9999913,
#     'raw_content': "# What is LangGraph?\n\n## LangGraph overview\n\nLangGraph, created by [LangChain](https://www.ibm.com/think/topics/langchain), is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize [large language models](https://www.ibm.com/think/topics/large-language-models) (LLMs) in a scalable and efficient manner. At its core, LangGraph uses the power of graph-based architectures to model and manage the intricate relationships between various components of an [AI agent workflow](https://www.ibm.com/think/topics/ai-agents).\n\nWhat does all this information mean? The following example can offer a clearer understanding of LangGraph: Think about these graph-based architectures as a powerful configurable map, a “Super-Map.” Users can envision the [AI workflow](https://www.ibm.com/think/topics/ai-workflow) as being “The Navigator” of this “Super-Map.” Finally, in this example, the user is “The Cartographer.” In this sense, the navigator charts out the optimal routes between points on the “Super-Map,” all of which are created by “The Cartographer.”\n\nTo recap, optimal routes within the graph-based architectures (“Super-Map”) are charted and explored by using the AI workflow\xa0(“The Navigator”). This analogy is a great place to start understanding LangGraph—and if you like maps then you are welcome for the bonus opportunity to see someone use the word cartographer.\n\n![LangGraph workflow](https://assets.ibm.com/is/image/ibm/langgraph?ts=1775068253616&dpr=off)\n\nLangGraph illuminates the processes within an AI workflow, allowing full transparency of the agent’s state. Within LangGraph, the “state” feature serves as a memory bank that records and tracks all the valuable information processed by the AI system. It’s similar to a digital notebook where the system captures and updates data as it moves through various stages of a workflow or graph analysis.\n\nFor example, if you were running agents to monitor the weather, this feature could track the number of times it snowed and make suggestions based on changing snowfall trends. This observability of how the system works to complete complex tasks is useful for beginners to understand more about state management. State management is helpful when it comes to debugging as it allows the application’s state to be centralized, thus often shortening the overall process.\n\nThis approach allows for more effective decision-making, improved scalability and enhanced overall performance. It also allows for more engagement with individuals who might be new to these processes or prefer a clearer picture of what is going on behind the scenes.\n\nLangGraph is also built on several key technologies, including [LangChain,](https://www.ibm.com/think/topics/langchain) a Python framework for building AI applications. LangChain includes a library for building and managing [LLMs](https://www.ibm.com/think/topics/large-language-models). LangGraph also uses the human-in-the-loop approach. By combining these technologies with a set of APIs and tools, LangGraph provides users with a versatile platform for developing AI solutions and workflows including [chatbots](https://www.ibm.com/think/topics/chatbots), state graphs and [other agent-based systems](https://www.ibm.com/think/topics/multiagent-system).\n\nDelve deeper into the world of LangGraph by exploring its key features, benefits and use cases. By the end of this article, you will have the knowledge and resources to take the next steps with LangGraph.\n\n## Key components of LangGraph\n\nLet’s begin by first understanding the key components that make up LangGraph. The framework is built around several key components that work together to enable users to create and manage complex AI workflows. These components include:\n\n#### Monitoring mechanism\n\n**Human-in-the-loop**: [Human-in-the-loop (HITL)](http ...
#    {'url': 'https://docs.langchain.com/oss/python/langgraph/overview',
#     'title': 'LangGraph overview - Docs by LangChain',
#     'content': 'LangGraph provides low-level supporting infrastructure for _any_ long-running, stateful workflow or agent. LangGraph does not abstract prompts or architecture, and provides the following central benefits:\n   Persistence: Build agents that persist through failures and can run for extended periods, resuming from where they left off.\n   Human-in-the-loop: Incorporate human oversight by inspecting and modifying agent state at any point.\n   Comprehensive memory: Create stateful agents with both short-term working memory for ongoing reasoning and long-term memory across sessions.\n   Debugging with LangSmith: Gain deep visibility into complex agent behavior with visualization tools that trace execution paths, capture state transitions, and provide detailed runtime metrics. [...] Trusted by companies shaping the future of agents— including Klarna, Uber, J.P. Morgan, and more— LangGraph is a low-level orchestration framework and runtime for building, managing, and deploying long-running, stateful agents.LangGraph is very low-level, and focused entirely on agent orchestration. Before using LangGraph, we recommend you familiarize yourself with some of the components used to build agents, starting with models and tools.We will commonly use LangChain components throughout the documentation to integrate models and tools, but you don’t need to use LangChain to use LangGraph. If you are just getting started with agents or want a higher-level abstraction, we recommend you use LangChain’s agents that provide prebuilt architectures for common LLM and tool-calling [...] prebuilt architectures for common LLM and tool-calling loops.LangGraph is focused on the underlying capabilities important for agent orchestration: durable execution, streaming, human-in-the-loop, and more.',
#     'score': 0.99994695,
#     'raw_content': '# LangGraph overview - Docs by LangChain\n\n[Skip to main content](https://docs.langchain.com/oss/python/langgraph/overview#content-area)\n\n[Docs by LangChain home page![Image 1: light logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://docs.langchain.com/)![Image 3: https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)Open source\n\nSearch...\n\nCtrl K\n\n*   [Ask AI](https://chat.langchain.com/)\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try LangSmith](https://smith.langchain.com/)\n*   [Try LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangGraph overview\n\n[Deep Agents](https://docs.langchain.com/oss/python/deepagents/overview)[LangChain](https://docs.langchain.com/oss/python/langchain/overview)[LangGraph](https://docs.langchain.com/oss/python/langgraph/overview)[Integrations](https://docs.langchain.com/oss/python/integrations/providers/overview)[Learn](https://docs.langchain.com/oss/python/learn)[Reference](https://docs.langchain.com/oss/python/reference/overview)[Contribute](https://docs.langchain.com/oss/python/contributing/overview)\n\nPython\n\n*   [Overview](https://docs.langchain.com/oss/python/langgraph/overview)\n\n### Get started\n\n*   [Install](https://docs.langchain.com/oss/python/langgraph/install)\n*   [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart)\n*   [Local server](https://docs.langchain.com/oss/python/langgraph/local-server)\n*   [Changelog](https://docs.langchain.com/oss/python/releases/changelog)\n*   [Thinking in LangGraph](https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph)\n*   [Workflows + agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents)\n\n### Capabilities\n\n*   [Persistence](https://docs.langchain.com/oss/python/langgraph/persistence)\n*   [Fault tolerance](https://docs.langchain.com/oss/python/langgraph/fault-tolerance)\n*   [Event streaming](https://docs.langchain.com/oss/python/langgraph/event-streaming)\n*   [Streaming](https://docs.langchain.com/oss/python/langgraph/streaming)\n*   [Interrupts](https://docs.langchain.com/oss/python/langgraph/interrupts)\n*   [Time travel](https://docs.langchain.com/oss/python/langgraph/use-time-travel)\n*   [Memory](https://docs.langchain.com/oss/python/langgraph/add-memory)\n*   [Subgraphs](https://docs.langchain.com/oss/python/langgraph/use-subgraphs)\n\n### Production\n\n*   [Application structure](https://docs.langchain.com/oss/python/langgraph/application-structure)\n*   [Test](https://docs.langchain.com/oss/python/langgraph/test)\n*   [Backward compatibility](https://docs.langchain.com/oss/python/langgraph/backward-compatibility)\n*   [LangSmith Studio](https://docs.langchain.com/oss/python/langgraph/studio)\n*   [Agent Chat UI](https://docs.langchain.com/oss/python/langgraph/ui)\n*   [LangSmith Deployment](https://docs.langchain.com/oss/python/langgraph/deploy)\n*   [LangSmith Observability](https://docs.langchain.com/oss/python/langgraph/observability)\n\n### Frontend\n\n*   [Overview](https://docs.langchain.com/oss/python/langgraph/frontend/overview)\n*   [Graph execution](https://docs.langchain.com/oss/python/langgraph/frontend/graph-execution)\n\n### LangGraph APIs\n\n*   Graph API  \n*   Functional API  \n*   [Runtime](https://docs.langchain.com/oss/python/langgraph/pregel)\n\n## On this page\n\n*   [Install](https://docs.langchain.com/oss/python/langgraph/overview#install)\n*   [Core benefits](https://docs.langchain.com/oss/python/langgraph/overview#c ...
#    {'url': 'https://duplocloud.com/blog/langchain-vs-langgraph',
#     'title': "LangChain vs. LangGraph: A Developer's Guide to Choosing Your ...",
#     'content': 'LangGraph: LangGraph takes an explicit approach to state management. You define a state object (like a Python dictionary or TypedDict) that gets updated as the workflow progresses. Each node can read and modify this state. This gives you granular control. It’s important for long-running applications or multi-agent systems where you need to persist data. These can include conversation history or task lists across sessions. LangGraph also supports checkpointers for short- and long-term memory. This makes it ideal for stateful applications.\n\nExample: In the LangGraph task management example above, the TaskState object persists the task list across interactions, allowing the assistant to “remember” previous tasks. [...] from langchain.chains import LLMChain\n\n# Define a prompt and chain\n\nprompt = PromptTemplate(input\\_variables=[“question”], template=”Answer this: {question}”)\n\nllm = OpenAI(model\\_name=”gpt-3.5-turbo”)\n\nchain = LLMChain(llm=llm, prompt=prompt)\n\n# Run the chain\n\nresult = chain.run(“What’s the capital of France?”)\n\nprint(result)  # Output: The capital of France is Paris.\n\nThis is LangChain’s bread and butter: a straightforward, sequential flow that’s easy to set up and debug.\n\nLangGraph: Now, imagine a flowchart where tasks can:\n\n Loop back\n Branch out\n Talk to each other like a team of AI agents\n\nThat’s what you’ll get with LangGraph. It’s a framework that models workflows as cyclical graphs with nodes (tasks) and edges (data flow or transitions). Each node can be an: [...] LangGraph: LangGraph is the maestro of dynamic, non-linear workflows. It’s specifically designed for scenarios where tasks might loop back. For example, a task management assistant might need to revisit previous tasks or handle conditional logic (“if the user says X, do Y”). They may also need to coordinate multiple agents (e.g., one for task creation, another for summarization). LangGraph’s graph structure makes this a breeze because it supports cycles and stateful interactions.\n\nKey Difference: LangChain is ideal for predictable, step-by-step processes. LangGraph handles complex, iterative, and multi-agent workflows with ease.\n\n3. State Management: Implicit vs. Explicit',
#     'score': 0.99977833,
#     'raw_content': '[![Logo](https://duplocloud.com/wp-content/uploads/2025/11/header-logo.svg)](https://duplocloud.com) [![Logo](https://duplocloud.com/wp-content/uploads/2025/11/header-logo-black.svg)](https://duplocloud.com)\n\n[See Demo](https://duplocloud.com/request-a-demo)\n\n  [Skip to content](#primary) \n\n# LangChain vs. LangGraph: A Developer’s Guide to Choosing Your AI Workflow\n\nAuthor: Joel Lim\n\nHere at DuploCloud, we’ve been navigating the tumultuous waters of AI in an effort to champion its use in automating DevOps workflows (and make using it simpler).\n\nThis has brought us face-to-face with some big questions about architectural components of AI-driven systems, such as LangChain vs. LangGraph. Let’s take a look.\n\nBoth **LangChain** and **LangGraph** are open-source frameworks from the LangChain ecosystem that sound similar but play very different roles in the AI orchestra. Whether you’re a non-technical dreamer or a code-slinging developer, this article breaks down the differences with a sprinkle of fun and a lot of technical meat. Let’s dive in!\n\n## **Key Takeaways**\n\n1. LangChain is best for linear, modular AI workflows that call for a quick setup and minimal complexity, so it’s ideal for prototypes, simple chatbots, and RAG pipelines.\n2. LangGraph excels in building complex, stateful, and multi-agent systems thanks to its graph-based architecture, explicit state management, and real-time streaming capabilities.\n3. LangGraph and LangChain can be used together, which lets developers combine the simplicity of chains with the power of dynamic graphs for robust AI applications.\n\n**For Non-Technical People: The Quick Scoop**\n\nPicture LangChain as a trusty Swiss Army knife for building AI apps. It’s great for straightforward tasks like:\n\n* Fetching data\n* Summarizing it\n* Answering questions\n\nAnd it can do it in a neat, step-by-step flow. Think of it as a conveyor belt. You put the data in, it gets processed, and then it comes out nice and shiny.\n\n**It’s easy to use, and it’s perfect for simple AI projects like chatbots or Q&A systems.**\n\nNow, LangGraph is like a 3D puzzle board for more complex AI adventures. It lets you create workflows where multiple AI “agents” talk to each other. They also loop back and make decisions based on what’s happening in real-time. It’s ideal for intricate systems. It’s like a virtual assistant that:\n\n* Juggles tasks\n* Revisits decisions\n* Collaborates with other AI buddies\n\n**If your project feels like a sci-fi plot with twists and turns, LangGraph’s your go-to.**\n\n**Bottom line**: Pick LangChain for simple, linear AI workflows. Go for LangGraph if your AI needs to think, loop, and collaborate like a team of brainy robots. Now, let’s get nerdy for the developers!\n\n**For Developers: The Technical Showdown**\n\nLangChain and LangGraph are both built to make LLMs more than just fancy text generators. They’re frameworks for orchestrating complex AI workflows. But they approach this mission with different philosophies, architectures, and superpowers. Let’s break it down into key areas: **architecture**, **workflow style**, **state management**, **use cases**, and **ease of use**. Buckle up, and let’s code our way through the differences!\n\n**1. Architecture: Chains vs. Graphs**\n\n**LangChain**: Think of LangChain as a pipeline architect. It’s built around the concept of **chains**, where tasks are strung together in a **Directed Acyclic Graph (DAG)**, a fancy way of saying “one-way street with no loops.” Each step (or “chain”) takes an input, processes it, and passes the output to the next step. For example, you might chain a document loader to fetch data, a summarizer to condense it, and an LLM (large language model) to answer questions based on the summary. It’s modular, flexible, and loves linear workflows.\n\nHere’s a quick LangChain example using Python and the LangChain Expression Language (LCEL):\n\npython\n\nfrom langchain.prompts import Pr ...
#    {'url': 'https://www.geeksforgeeks.org/machine-learning/what-is-langgraph',
#     'title': 'What is LangGraph - GeeksforGeeks',
#     'content': 'geeksforgeeks\n\n# What is LangGraph\n\nLangGraph is an open-source framework from LangChain designed to build and manage AI agent workflows using graph-based structures. It allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable and easier to control.\n\nlangchain_vs_langgraph_pipelines\n\nLangChain uses a straightforward step-by-step pipeline where each task follows a fixed sequence from input to output while LangGraph allows flexible workflows with branching and parallel steps, making it better suited for complex, decision-based applications.\n\n## Workflow of LangGraph\n\nThe diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.\n\nwhat_is_langgraph_ [...] if classification == "greeting":\n        response = "Hello! How can I help you today?"\n    elif classification == "search":\n        response = ask_gemini(question)\n    else:\n        response = "I\'m not sure how to respond to that."\n\n    return {\n        state,\n        "response": response\n    }\n\n````\n\n### Step 6: Build LangGraph Workflow\n\n````\nimport networkx as nx\nimport matplotlib.pyplot as plt\nfrom langgraph.graph import StateGraph\n\nbuilder = StateGraph(GraphState)\nbuilder.add_node("classify", classify)\nbuilder.add_node("respond", respond)\nbuilder.set_entry_point("classify")\nbuilder.add_edge("classify", "respond")\nbuilder.set_finish_point("respond")\napp = builder.compile()\n\ndef visualize_workflow(builder):\n    G = nx.DiGraph() [...] def visualize_workflow(builder):\n    G = nx.DiGraph()\n\n    for node in builder.nodes:\n        G.add_node(node)\n    for edge in builder.edges:\n        G.add_edge(edge, edge)\n\n    pos = nx.spring_layout(G)\n    nx.draw(G, pos, with_labels=True, node_size=3000,\n            node_color="skyblue", font_size=12, font_weight="bold", arrows=True)\n\n    plt.title("Langchain Workflow Visualization")\n    plt.show()\n\nvisualize_workflow(builder)\n\n````\n\nOutput:\n\nLangGraph\n\n### Step 7: Interactive Chat Interface\n\n````\nprint("=== Gemini-Powered Chatbot ===")\nprint("Type your question below. Type \'exit\' to quit.\\n")\n\nwhile True:\n    user_input = input("You: ")\n    if user_input.strip().lower() in [\'exit\', \'quit\']:\n        print("Bot: Goodbye!")\n        break',
#     'score': 0.9997713,
#     'raw_content': '![geeksforgeeks](https://media.geeksforgeeks.org/gfg-gg-logo.svg)\n\n# What is LangGraph\n\nLangGraph is an open-source framework from LangChain designed to build and manage AI agent workflows using graph-based structures. It allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable and easier to control.\n\n![langchain_vs_langgraph_pipelines](https://media.geeksforgeeks.org/wp-content/uploads/20260320152116700448/langchain_vs_langgraph_pipelines.webp)\n\nLangChain uses a straightforward step-by-step pipeline where each task follows a fixed sequence from input to output while LangGraph allows flexible workflows with branching and parallel steps, making it better suited for complex, decision-based applications.\n\n## Workflow of LangGraph\n\nThe diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.\n\n![what_is_langgraph_](https://media.geeksforgeeks.org/wp-content/uploads/20251212160007527277/what_is_langgraph_.webp)\n\nHere\'s a step by step interpretation of the flow:\n\n## Components\n\nThese core components work together smoothly to help developers build, customize and manage complex AI driven workflows.\n\n## How LangGraph Scales\n\n## Building a Simple Chatbot with LangGraph\n\nLangGraph makes it easy to build structured, stateful applications like chatbots. In this example we’ll learn how to create a basic chatbot that can classify user input as either a greet, search query and respond accordingly.\n\n### Step 1: Install the Dependencies\n\nInstalls the required dependencies,\n\n````\n!pip install langgraph langchain google-generativeai\n\n````\n\n### Step 2: Setup Gemini API\n\nTo know how to access Gemini API refer to : [How to Access and Use Google Gemini API Key (with Examples)](https://www.geeksforgeeks.org/artificial-intelligence/how-to-use-google-gemini-api-key/)\n\n````\nimport google.generativeai as genai\n\ngenai.configure(api_key="YOUR_API_KEY")\n\nmodel = genai.GenerativeModel("gemini-1.5-flash")\n\ndef ask_gemini(prompt: str) -> str:\n    try:\n        response = model.generate_content(prompt)\n        return response.text\n    except Exception as e:\n        return "Sorry, something went wrong with the Gemini API."\n\n````\n\n### Step 3: Define Chatbot State\n\nWe will import\xa0Optional\xa0and\xa0TypedDict\xa0for strict type checking and creates a\xa0GraphState\xa0type:\n\n````\nfrom typing import Optional\nfrom typing_extensions import TypedDict\n\nclass GraphState(TypedDict):\n    question: Optional[str]\n    classification: Optional[str]\n    response: Optional[str]\n\n````\n\n### Step 4: Classify Input\n\nWe define\xa0classify, which takes the workflow state and analyzes the user\'s question.\n\n````\ndef classify(state: GraphState) -> GraphState:\n    question = state.get("question", "").lower()\n    if any(word in question for word in ["hello", "hi", "hey", "good morning", "good evening"]):\n        classification = "greeting"\n    else:\n        classification = "search"\n\n    return {\n        **state,\n        "classification": classification\n    }\n\n````\n\n### Step 5: Respond Using Gemini (or Greeting)\n\nThis define\xa0respond which generates appropriate output based on classification.\n\n````\ndef respond(state: GraphState) -> GraphState:\n    classification = state.get("classification")\n    question = state.get("question")\n\n    if classification == "greeting":\n        response = "Hello! How can I help you today?"\n    elif classification == "search":\n        response = ask_gemini(question)\n    else:\n        response = "I\'m not sure how to respond to that."\n\n    return {\n        **state,\n        "response": response\n    }\n\n````\n\n### Step 6: Build LangGraph Workflow\n\n````\nimport networkx as nx\nimport matplotlib.pyplot as plt\nfrom langgraph.graph import StateGraph\n\nbuilder = StateGraph(GraphState)\nbuilder.add_node("classify", classify)\nbui ...
#    {'url': 'https://www.coursera.org/articles/langgraph',
#     'title': 'Understanding LangGraph Data Visualization Software | Coursera',
#     'content': '## What is LangGraph?\n\nLangGraph is an open-source library within the LangChain ecosystem that enables developers to build multi-agent applications using large language models (LLMs). While traditional AI workflows are often linear and rigid, LangGraph uses graph-based architectures to manage complex relationships between components. LangGraph provides a flexible way to coordinate and execute multiple LLM “agents” in complex workflows; by using "cycles" and "state management", it allows AI agents to solve large-scale problems that require iterative reasoning and human-like step-by-step logic.\n\n## 3 key features of LangGraph\n\n1. Graph-based Structure: Retains information across stages, making it easy to add conditional steps or "memory" to a chatbot.',
#     'score': 0.9997408,
#     'raw_content': '# Understanding LangGraph Data Visualization Software\n\nWritten by Coursera Staff • Updated on\n\nDiscover how LangGraph enhances NLP by transforming text into structured visual graphs. Learn its key features, real-world applications, and best practices to optimize AI workflows. Get started today with expert insights and practical resources.\n\n![[Featured Image] Professionals collaborate on a project and discuss LangGraph with a laptop displaying an international sales graph.\n](https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/wp1lcwdav1p1/3b1Ue0cPoLIoTVGKzSsgr0/4abb81dc392b7bfdc613b0f5c6c80f60/GettyImages-2064277143.jpg?w=1500&h=680&q=60&fit=fill&f=faces&fm=jpg&fl=progressive&auto=format%2Ccompress&dpr=1&w=1000)\n\n## Key Takeaways\n\nLangGraph is a specialized open-source framework within the LangChain ecosystem designed to build and manage multi-agent applications and complex AI workflows using large language models.\n\n* LangGraph enables developers to coordinate and execute multiple LLM agents through graph-based architectures that introduce robust state management and conditional logic.\n\n* This cyclical framework allows workflows to retain information across different stages, remember previous inputs, and adjust behavior based on real-time data.\n\n* You can explore the official LangChain documentation and tutorials to familiarize yourself with key features and build full-fledged chatbots.\n\nRead on to learn more about LangGraph, including its key features, real-world industry applications, and best practices for development. Build job-ready skills for an in-demand career by enrolling in the IBM AI Engineering Professional Certificate.\n\n## **What is LangGraph?**\n\nLangGraph is an open-source library within the LangChain ecosystem that enables developers to build multi-agent applications using large language models ([LLMs](https://www.coursera.org/articles/large-language-models)). While traditional AI workflows are often linear and rigid, LangGraph uses graph-based architectures to manage complex relationships between components. LangGraph provides a flexible way to coordinate and execute multiple LLM “agents” in complex workflows; by using "cycles" and "state management", it allows AI agents to solve large-scale problems that require iterative reasoning and human-like step-by-step logic.\n\n## **3 key features of LangGraph**\n\n**1. Graph-based Structure:** Retains information across stages, making it easy to add conditional steps or "memory" to a chatbot.\n\n**2. Interactivity & Streaming:** Supports long-term user interaction with built-in streaming (partial outputs) and LangGraph Studio for real-time visual debugging.\n\n**3. Model Integration:** Seamless compatibility with various APIs and GPT variants, including the ability to transform raw text into structured graph data via the LLMGraphTransformer.\n\n## **Best practices for development**\n\nTo build scalable AI agents, focus on these LangGraph-specific orchestration capabilities:\n\n* **State Schema Design:** Explicitly define your state schema to control how agents share and update information. A well-structured state prevents data conflicts and ensures that each node has the exact context it needs to execute.\n\n* **Human-in-the-Loop (HITL):** Use LangGraph’s "interrupt" functionality to integrate human oversight into automated workflows. This is critical for tasks requiring high accountability, such as approving a final draft or confirming a financial transaction before the agent proceeds.\n\n* **Modular Architecture:** Break workflows into smaller, independent nodes. This makes the system easier to test and debug, and allows you to reuse specific agent logic across different projects.\n\n* **Rigorous Validation:** Use unit and integration tests to verify state transitions. Early testing prevents costly logic errors that can occur when complex, cyclic dependencies are introduced.\n\n* ** ...
#   'response_time': 0.0,
#   'request_id': '750bd630-9fa3-41f9-a99d-780e6942e3b1'}]

# %%
len(docs)
# Out:
# 1

# %%
docs[0]
# Out:
# {'query': 'langgraph',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.ibm.com/think/topics/langgraph',
#    'title': 'What is LangGraph?',
#    'content': '# What is LangGraph?\n\n## LangGraph overview\n\nLangGraph, created by LangChain, is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize large language models (LLMs) in a scalable and efficient manner. At its core, LangGraph uses the power of graph-based architectures to model and manage the intricate relationships between various components of an AI agent workflow. [...] Debugging: The capabilities do not end with building a graph, debugging features are included to ensure the graph is accurate and reliable. LangGraph Studio, with its cutting-edge integrated development environment (IDE), helps visualize and debug LangGraph applications.\n\n## Future developments\n\nEnhanced natural language processing (NLP): LangGraph will have more advanced NLP capabilities, allowing it to better understand natural language and provide more accurate responses.\n\nImproved machine learning: LangGraph will have improved machine learning capabilities, allowing it to learn and improve over time.\n\nSupport for new platforms: LangGraph will support new platforms, such as mobile devices and edge computing to make its technology more accessible.\n\n## Authors [...] LangGraph is also built on several key technologies, including LangChain, a Python framework for building AI applications. LangChain includes a library for building and managing LLMs. LangGraph also uses the human-in-the-loop approach. By combining these technologies with a set of APIs and tools, LangGraph provides users with a versatile platform for developing AI solutions and workflows including chatbots, state graphs and other agent-based systems.\n\nDelve deeper into the world of LangGraph by exploring its key features, benefits and use cases. By the end of this article, you will have the knowledge and resources to take the next steps with LangGraph.\n\n## Key components of LangGraph',
#    'score': 0.9999913,
#    'raw_content': "# What is LangGraph?\n\n## LangGraph overview\n\nLangGraph, created by [LangChain](https://www.ibm.com/think/topics/langchain), is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize [large language models](https://www.ibm.com/think/topics/large-language-models) (LLMs) in a scalable and efficient manner. At its core, LangGraph uses the power of graph-based architectures to model and manage the intricate relationships between various components of an [AI agent workflow](https://www.ibm.com/think/topics/ai-agents).\n\nWhat does all this information mean? The following example can offer a clearer understanding of LangGraph: Think about these graph-based architectures as a powerful configurable map, a “Super-Map.” Users can envision the [AI workflow](https://www.ibm.com/think/topics/ai-workflow) as being “The Navigator” of this “Super-Map.” Finally, in this example, the user is “The Cartographer.” In this sense, the navigator charts out the optimal routes between points on the “Super-Map,” all of which are created by “The Cartographer.”\n\nTo recap, optimal routes within the graph-based architectures (“Super-Map”) are charted and explored by using the AI workflow\xa0(“The Navigator”). This analogy is a great place to start understanding LangGraph—and if you like maps then you are welcome for the bonus opportunity to see someone use the word cartographer.\n\n![LangGraph workflow](https://assets.ibm.com/is/image/ibm/langgraph?ts=1775068253616&dpr=off)\n\nLangGraph illuminates the processes within an AI workflow, allowing full transparency of the agent’s state. Within LangGraph, the “state” feature serves as a memory bank that records and tracks all the valuable information processed by the AI system. It’s similar to a digital notebook where the system captures and updates data as it moves through various stages of a workflow or graph analysis.\n\nFor example, if you were running agents to monitor the weather, this feature could track the number of times it snowed and make suggestions based on changing snowfall trends. This observability of how the system works to complete complex tasks is useful for beginners to understand more about state management. State management is helpful when it comes to debugging as it allows the application’s state to be centralized, thus often shortening the overall process.\n\nThis approach allows for more effective decision-making, improved scalability and enhanced overall performance. It also allows for more engagement with individuals who might be new to these processes or prefer a clearer picture of what is going on behind the scenes.\n\nLangGraph is also built on several key technologies, including [LangChain,](https://www.ibm.com/think/topics/langchain) a Python framework for building AI applications. LangChain includes a library for building and managing [LLMs](https://www.ibm.com/think/topics/large-language-models). LangGraph also uses the human-in-the-loop approach. By combining these technologies with a set of APIs and tools, LangGraph provides users with a versatile platform for developing AI solutions and workflows including [chatbots](https://www.ibm.com/think/topics/chatbots), state graphs and [other agent-based systems](https://www.ibm.com/think/topics/multiagent-system).\n\nDelve deeper into the world of LangGraph by exploring its key features, benefits and use cases. By the end of this article, you will have the knowledge and resources to take the next steps with LangGraph.\n\n## Key components of LangGraph\n\nLet’s begin by first understanding the key components that make up LangGraph. The framework is built around several key components that work together to enable users to create and manage complex AI workflows. These components include:\n\n#### Monitoring mechanism\n\n**Human-in-the-loop**: [Human-in-the-loop (HITL)](https ...
#   {'url': 'https://docs.langchain.com/oss/python/langgraph/overview',
#    'title': 'LangGraph overview - Docs by LangChain',
#    'content': 'LangGraph provides low-level supporting infrastructure for _any_ long-running, stateful workflow or agent. LangGraph does not abstract prompts or architecture, and provides the following central benefits:\n   Persistence: Build agents that persist through failures and can run for extended periods, resuming from where they left off.\n   Human-in-the-loop: Incorporate human oversight by inspecting and modifying agent state at any point.\n   Comprehensive memory: Create stateful agents with both short-term working memory for ongoing reasoning and long-term memory across sessions.\n   Debugging with LangSmith: Gain deep visibility into complex agent behavior with visualization tools that trace execution paths, capture state transitions, and provide detailed runtime metrics. [...] Trusted by companies shaping the future of agents— including Klarna, Uber, J.P. Morgan, and more— LangGraph is a low-level orchestration framework and runtime for building, managing, and deploying long-running, stateful agents.LangGraph is very low-level, and focused entirely on agent orchestration. Before using LangGraph, we recommend you familiarize yourself with some of the components used to build agents, starting with models and tools.We will commonly use LangChain components throughout the documentation to integrate models and tools, but you don’t need to use LangChain to use LangGraph. If you are just getting started with agents or want a higher-level abstraction, we recommend you use LangChain’s agents that provide prebuilt architectures for common LLM and tool-calling [...] prebuilt architectures for common LLM and tool-calling loops.LangGraph is focused on the underlying capabilities important for agent orchestration: durable execution, streaming, human-in-the-loop, and more.',
#    'score': 0.99994695,
#    'raw_content': '# LangGraph overview - Docs by LangChain\n\n[Skip to main content](https://docs.langchain.com/oss/python/langgraph/overview#content-area)\n\n[Docs by LangChain home page![Image 1: light logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://docs.langchain.com/)![Image 3: https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)Open source\n\nSearch...\n\nCtrl K\n\n*   [Ask AI](https://chat.langchain.com/)\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try LangSmith](https://smith.langchain.com/)\n*   [Try LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangGraph overview\n\n[Deep Agents](https://docs.langchain.com/oss/python/deepagents/overview)[LangChain](https://docs.langchain.com/oss/python/langchain/overview)[LangGraph](https://docs.langchain.com/oss/python/langgraph/overview)[Integrations](https://docs.langchain.com/oss/python/integrations/providers/overview)[Learn](https://docs.langchain.com/oss/python/learn)[Reference](https://docs.langchain.com/oss/python/reference/overview)[Contribute](https://docs.langchain.com/oss/python/contributing/overview)\n\nPython\n\n*   [Overview](https://docs.langchain.com/oss/python/langgraph/overview)\n\n### Get started\n\n*   [Install](https://docs.langchain.com/oss/python/langgraph/install)\n*   [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart)\n*   [Local server](https://docs.langchain.com/oss/python/langgraph/local-server)\n*   [Changelog](https://docs.langchain.com/oss/python/releases/changelog)\n*   [Thinking in LangGraph](https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph)\n*   [Workflows + agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents)\n\n### Capabilities\n\n*   [Persistence](https://docs.langchain.com/oss/python/langgraph/persistence)\n*   [Fault tolerance](https://docs.langchain.com/oss/python/langgraph/fault-tolerance)\n*   [Event streaming](https://docs.langchain.com/oss/python/langgraph/event-streaming)\n*   [Streaming](https://docs.langchain.com/oss/python/langgraph/streaming)\n*   [Interrupts](https://docs.langchain.com/oss/python/langgraph/interrupts)\n*   [Time travel](https://docs.langchain.com/oss/python/langgraph/use-time-travel)\n*   [Memory](https://docs.langchain.com/oss/python/langgraph/add-memory)\n*   [Subgraphs](https://docs.langchain.com/oss/python/langgraph/use-subgraphs)\n\n### Production\n\n*   [Application structure](https://docs.langchain.com/oss/python/langgraph/application-structure)\n*   [Test](https://docs.langchain.com/oss/python/langgraph/test)\n*   [Backward compatibility](https://docs.langchain.com/oss/python/langgraph/backward-compatibility)\n*   [LangSmith Studio](https://docs.langchain.com/oss/python/langgraph/studio)\n*   [Agent Chat UI](https://docs.langchain.com/oss/python/langgraph/ui)\n*   [LangSmith Deployment](https://docs.langchain.com/oss/python/langgraph/deploy)\n*   [LangSmith Observability](https://docs.langchain.com/oss/python/langgraph/observability)\n\n### Frontend\n\n*   [Overview](https://docs.langchain.com/oss/python/langgraph/frontend/overview)\n*   [Graph execution](https://docs.langchain.com/oss/python/langgraph/frontend/graph-execution)\n\n### LangGraph APIs\n\n*   Graph API  \n*   Functional API  \n*   [Runtime](https://docs.langchain.com/oss/python/langgraph/pregel)\n\n## On this page\n\n*   [Install](https://docs.langchain.com/oss/python/langgraph/overview#install)\n*   [Core benefits](https://docs.langchain.com/oss/python/langgraph/overview#co ...
#   {'url': 'https://duplocloud.com/blog/langchain-vs-langgraph',
#    'title': "LangChain vs. LangGraph: A Developer's Guide to Choosing Your ...",
#    'content': 'LangGraph: LangGraph takes an explicit approach to state management. You define a state object (like a Python dictionary or TypedDict) that gets updated as the workflow progresses. Each node can read and modify this state. This gives you granular control. It’s important for long-running applications or multi-agent systems where you need to persist data. These can include conversation history or task lists across sessions. LangGraph also supports checkpointers for short- and long-term memory. This makes it ideal for stateful applications.\n\nExample: In the LangGraph task management example above, the TaskState object persists the task list across interactions, allowing the assistant to “remember” previous tasks. [...] from langchain.chains import LLMChain\n\n# Define a prompt and chain\n\nprompt = PromptTemplate(input\\_variables=[“question”], template=”Answer this: {question}”)\n\nllm = OpenAI(model\\_name=”gpt-3.5-turbo”)\n\nchain = LLMChain(llm=llm, prompt=prompt)\n\n# Run the chain\n\nresult = chain.run(“What’s the capital of France?”)\n\nprint(result)  # Output: The capital of France is Paris.\n\nThis is LangChain’s bread and butter: a straightforward, sequential flow that’s easy to set up and debug.\n\nLangGraph: Now, imagine a flowchart where tasks can:\n\n Loop back\n Branch out\n Talk to each other like a team of AI agents\n\nThat’s what you’ll get with LangGraph. It’s a framework that models workflows as cyclical graphs with nodes (tasks) and edges (data flow or transitions). Each node can be an: [...] LangGraph: LangGraph is the maestro of dynamic, non-linear workflows. It’s specifically designed for scenarios where tasks might loop back. For example, a task management assistant might need to revisit previous tasks or handle conditional logic (“if the user says X, do Y”). They may also need to coordinate multiple agents (e.g., one for task creation, another for summarization). LangGraph’s graph structure makes this a breeze because it supports cycles and stateful interactions.\n\nKey Difference: LangChain is ideal for predictable, step-by-step processes. LangGraph handles complex, iterative, and multi-agent workflows with ease.\n\n3. State Management: Implicit vs. Explicit',
#    'score': 0.99977833,
#    'raw_content': '[![Logo](https://duplocloud.com/wp-content/uploads/2025/11/header-logo.svg)](https://duplocloud.com) [![Logo](https://duplocloud.com/wp-content/uploads/2025/11/header-logo-black.svg)](https://duplocloud.com)\n\n[See Demo](https://duplocloud.com/request-a-demo)\n\n  [Skip to content](#primary) \n\n# LangChain vs. LangGraph: A Developer’s Guide to Choosing Your AI Workflow\n\nAuthor: Joel Lim\n\nHere at DuploCloud, we’ve been navigating the tumultuous waters of AI in an effort to champion its use in automating DevOps workflows (and make using it simpler).\n\nThis has brought us face-to-face with some big questions about architectural components of AI-driven systems, such as LangChain vs. LangGraph. Let’s take a look.\n\nBoth **LangChain** and **LangGraph** are open-source frameworks from the LangChain ecosystem that sound similar but play very different roles in the AI orchestra. Whether you’re a non-technical dreamer or a code-slinging developer, this article breaks down the differences with a sprinkle of fun and a lot of technical meat. Let’s dive in!\n\n## **Key Takeaways**\n\n1. LangChain is best for linear, modular AI workflows that call for a quick setup and minimal complexity, so it’s ideal for prototypes, simple chatbots, and RAG pipelines.\n2. LangGraph excels in building complex, stateful, and multi-agent systems thanks to its graph-based architecture, explicit state management, and real-time streaming capabilities.\n3. LangGraph and LangChain can be used together, which lets developers combine the simplicity of chains with the power of dynamic graphs for robust AI applications.\n\n**For Non-Technical People: The Quick Scoop**\n\nPicture LangChain as a trusty Swiss Army knife for building AI apps. It’s great for straightforward tasks like:\n\n* Fetching data\n* Summarizing it\n* Answering questions\n\nAnd it can do it in a neat, step-by-step flow. Think of it as a conveyor belt. You put the data in, it gets processed, and then it comes out nice and shiny.\n\n**It’s easy to use, and it’s perfect for simple AI projects like chatbots or Q&A systems.**\n\nNow, LangGraph is like a 3D puzzle board for more complex AI adventures. It lets you create workflows where multiple AI “agents” talk to each other. They also loop back and make decisions based on what’s happening in real-time. It’s ideal for intricate systems. It’s like a virtual assistant that:\n\n* Juggles tasks\n* Revisits decisions\n* Collaborates with other AI buddies\n\n**If your project feels like a sci-fi plot with twists and turns, LangGraph’s your go-to.**\n\n**Bottom line**: Pick LangChain for simple, linear AI workflows. Go for LangGraph if your AI needs to think, loop, and collaborate like a team of brainy robots. Now, let’s get nerdy for the developers!\n\n**For Developers: The Technical Showdown**\n\nLangChain and LangGraph are both built to make LLMs more than just fancy text generators. They’re frameworks for orchestrating complex AI workflows. But they approach this mission with different philosophies, architectures, and superpowers. Let’s break it down into key areas: **architecture**, **workflow style**, **state management**, **use cases**, and **ease of use**. Buckle up, and let’s code our way through the differences!\n\n**1. Architecture: Chains vs. Graphs**\n\n**LangChain**: Think of LangChain as a pipeline architect. It’s built around the concept of **chains**, where tasks are strung together in a **Directed Acyclic Graph (DAG)**, a fancy way of saying “one-way street with no loops.” Each step (or “chain”) takes an input, processes it, and passes the output to the next step. For example, you might chain a document loader to fetch data, a summarizer to condense it, and an LLM (large language model) to answer questions based on the summary. It’s modular, flexible, and loves linear workflows.\n\nHere’s a quick LangChain example using Python and the LangChain Expression Language (LCEL):\n\npython\n\nfrom langchain.prompts import Pro ...
#   {'url': 'https://www.geeksforgeeks.org/machine-learning/what-is-langgraph',
#    'title': 'What is LangGraph - GeeksforGeeks',
#    'content': 'geeksforgeeks\n\n# What is LangGraph\n\nLangGraph is an open-source framework from LangChain designed to build and manage AI agent workflows using graph-based structures. It allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable and easier to control.\n\nlangchain_vs_langgraph_pipelines\n\nLangChain uses a straightforward step-by-step pipeline where each task follows a fixed sequence from input to output while LangGraph allows flexible workflows with branching and parallel steps, making it better suited for complex, decision-based applications.\n\n## Workflow of LangGraph\n\nThe diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.\n\nwhat_is_langgraph_ [...] if classification == "greeting":\n        response = "Hello! How can I help you today?"\n    elif classification == "search":\n        response = ask_gemini(question)\n    else:\n        response = "I\'m not sure how to respond to that."\n\n    return {\n        state,\n        "response": response\n    }\n\n````\n\n### Step 6: Build LangGraph Workflow\n\n````\nimport networkx as nx\nimport matplotlib.pyplot as plt\nfrom langgraph.graph import StateGraph\n\nbuilder = StateGraph(GraphState)\nbuilder.add_node("classify", classify)\nbuilder.add_node("respond", respond)\nbuilder.set_entry_point("classify")\nbuilder.add_edge("classify", "respond")\nbuilder.set_finish_point("respond")\napp = builder.compile()\n\ndef visualize_workflow(builder):\n    G = nx.DiGraph() [...] def visualize_workflow(builder):\n    G = nx.DiGraph()\n\n    for node in builder.nodes:\n        G.add_node(node)\n    for edge in builder.edges:\n        G.add_edge(edge, edge)\n\n    pos = nx.spring_layout(G)\n    nx.draw(G, pos, with_labels=True, node_size=3000,\n            node_color="skyblue", font_size=12, font_weight="bold", arrows=True)\n\n    plt.title("Langchain Workflow Visualization")\n    plt.show()\n\nvisualize_workflow(builder)\n\n````\n\nOutput:\n\nLangGraph\n\n### Step 7: Interactive Chat Interface\n\n````\nprint("=== Gemini-Powered Chatbot ===")\nprint("Type your question below. Type \'exit\' to quit.\\n")\n\nwhile True:\n    user_input = input("You: ")\n    if user_input.strip().lower() in [\'exit\', \'quit\']:\n        print("Bot: Goodbye!")\n        break',
#    'score': 0.9997713,
#    'raw_content': '![geeksforgeeks](https://media.geeksforgeeks.org/gfg-gg-logo.svg)\n\n# What is LangGraph\n\nLangGraph is an open-source framework from LangChain designed to build and manage AI agent workflows using graph-based structures. It allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable and easier to control.\n\n![langchain_vs_langgraph_pipelines](https://media.geeksforgeeks.org/wp-content/uploads/20260320152116700448/langchain_vs_langgraph_pipelines.webp)\n\nLangChain uses a straightforward step-by-step pipeline where each task follows a fixed sequence from input to output while LangGraph allows flexible workflows with branching and parallel steps, making it better suited for complex, decision-based applications.\n\n## Workflow of LangGraph\n\nThe diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.\n\n![what_is_langgraph_](https://media.geeksforgeeks.org/wp-content/uploads/20251212160007527277/what_is_langgraph_.webp)\n\nHere\'s a step by step interpretation of the flow:\n\n## Components\n\nThese core components work together smoothly to help developers build, customize and manage complex AI driven workflows.\n\n## How LangGraph Scales\n\n## Building a Simple Chatbot with LangGraph\n\nLangGraph makes it easy to build structured, stateful applications like chatbots. In this example we’ll learn how to create a basic chatbot that can classify user input as either a greet, search query and respond accordingly.\n\n### Step 1: Install the Dependencies\n\nInstalls the required dependencies,\n\n````\n!pip install langgraph langchain google-generativeai\n\n````\n\n### Step 2: Setup Gemini API\n\nTo know how to access Gemini API refer to : [How to Access and Use Google Gemini API Key (with Examples)](https://www.geeksforgeeks.org/artificial-intelligence/how-to-use-google-gemini-api-key/)\n\n````\nimport google.generativeai as genai\n\ngenai.configure(api_key="YOUR_API_KEY")\n\nmodel = genai.GenerativeModel("gemini-1.5-flash")\n\ndef ask_gemini(prompt: str) -> str:\n    try:\n        response = model.generate_content(prompt)\n        return response.text\n    except Exception as e:\n        return "Sorry, something went wrong with the Gemini API."\n\n````\n\n### Step 3: Define Chatbot State\n\nWe will import\xa0Optional\xa0and\xa0TypedDict\xa0for strict type checking and creates a\xa0GraphState\xa0type:\n\n````\nfrom typing import Optional\nfrom typing_extensions import TypedDict\n\nclass GraphState(TypedDict):\n    question: Optional[str]\n    classification: Optional[str]\n    response: Optional[str]\n\n````\n\n### Step 4: Classify Input\n\nWe define\xa0classify, which takes the workflow state and analyzes the user\'s question.\n\n````\ndef classify(state: GraphState) -> GraphState:\n    question = state.get("question", "").lower()\n    if any(word in question for word in ["hello", "hi", "hey", "good morning", "good evening"]):\n        classification = "greeting"\n    else:\n        classification = "search"\n\n    return {\n        **state,\n        "classification": classification\n    }\n\n````\n\n### Step 5: Respond Using Gemini (or Greeting)\n\nThis define\xa0respond which generates appropriate output based on classification.\n\n````\ndef respond(state: GraphState) -> GraphState:\n    classification = state.get("classification")\n    question = state.get("question")\n\n    if classification == "greeting":\n        response = "Hello! How can I help you today?"\n    elif classification == "search":\n        response = ask_gemini(question)\n    else:\n        response = "I\'m not sure how to respond to that."\n\n    return {\n        **state,\n        "response": response\n    }\n\n````\n\n### Step 6: Build LangGraph Workflow\n\n````\nimport networkx as nx\nimport matplotlib.pyplot as plt\nfrom langgraph.graph import StateGraph\n\nbuilder = StateGraph(GraphState)\nbuilder.add_node("classify", classify)\nbuil ...
#   {'url': 'https://www.coursera.org/articles/langgraph',
#    'title': 'Understanding LangGraph Data Visualization Software | Coursera',
#    'content': '## What is LangGraph?\n\nLangGraph is an open-source library within the LangChain ecosystem that enables developers to build multi-agent applications using large language models (LLMs). While traditional AI workflows are often linear and rigid, LangGraph uses graph-based architectures to manage complex relationships between components. LangGraph provides a flexible way to coordinate and execute multiple LLM “agents” in complex workflows; by using "cycles" and "state management", it allows AI agents to solve large-scale problems that require iterative reasoning and human-like step-by-step logic.\n\n## 3 key features of LangGraph\n\n1. Graph-based Structure: Retains information across stages, making it easy to add conditional steps or "memory" to a chatbot.',
#    'score': 0.9997408,
#    'raw_content': '# Understanding LangGraph Data Visualization Software\n\nWritten by Coursera Staff • Updated on\n\nDiscover how LangGraph enhances NLP by transforming text into structured visual graphs. Learn its key features, real-world applications, and best practices to optimize AI workflows. Get started today with expert insights and practical resources.\n\n![[Featured Image] Professionals collaborate on a project and discuss LangGraph with a laptop displaying an international sales graph.\n](https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/wp1lcwdav1p1/3b1Ue0cPoLIoTVGKzSsgr0/4abb81dc392b7bfdc613b0f5c6c80f60/GettyImages-2064277143.jpg?w=1500&h=680&q=60&fit=fill&f=faces&fm=jpg&fl=progressive&auto=format%2Ccompress&dpr=1&w=1000)\n\n## Key Takeaways\n\nLangGraph is a specialized open-source framework within the LangChain ecosystem designed to build and manage multi-agent applications and complex AI workflows using large language models.\n\n* LangGraph enables developers to coordinate and execute multiple LLM agents through graph-based architectures that introduce robust state management and conditional logic.\n\n* This cyclical framework allows workflows to retain information across different stages, remember previous inputs, and adjust behavior based on real-time data.\n\n* You can explore the official LangChain documentation and tutorials to familiarize yourself with key features and build full-fledged chatbots.\n\nRead on to learn more about LangGraph, including its key features, real-world industry applications, and best practices for development. Build job-ready skills for an in-demand career by enrolling in the IBM AI Engineering Professional Certificate.\n\n## **What is LangGraph?**\n\nLangGraph is an open-source library within the LangChain ecosystem that enables developers to build multi-agent applications using large language models ([LLMs](https://www.coursera.org/articles/large-language-models)). While traditional AI workflows are often linear and rigid, LangGraph uses graph-based architectures to manage complex relationships between components. LangGraph provides a flexible way to coordinate and execute multiple LLM “agents” in complex workflows; by using "cycles" and "state management", it allows AI agents to solve large-scale problems that require iterative reasoning and human-like step-by-step logic.\n\n## **3 key features of LangGraph**\n\n**1. Graph-based Structure:** Retains information across stages, making it easy to add conditional steps or "memory" to a chatbot.\n\n**2. Interactivity & Streaming:** Supports long-term user interaction with built-in streaming (partial outputs) and LangGraph Studio for real-time visual debugging.\n\n**3. Model Integration:** Seamless compatibility with various APIs and GPT variants, including the ability to transform raw text into structured graph data via the LLMGraphTransformer.\n\n## **Best practices for development**\n\nTo build scalable AI agents, focus on these LangGraph-specific orchestration capabilities:\n\n* **State Schema Design:** Explicitly define your state schema to control how agents share and update information. A well-structured state prevents data conflicts and ensures that each node has the exact context it needs to execute.\n\n* **Human-in-the-Loop (HITL):** Use LangGraph’s "interrupt" functionality to integrate human oversight into automated workflows. This is critical for tasks requiring high accountability, such as approving a final draft or confirming a financial transaction before the agent proceeds.\n\n* **Modular Architecture:** Break workflows into smaller, independent nodes. This makes the system easier to test and debug, and allows you to reuse specific agent logic across different projects.\n\n* **Rigorous Validation:** Use unit and integration tests to verify state transitions. Early testing prevents costly logic errors that can occur when complex, cyclic dependencies are introduced.\n\n* **P ...
#  'response_time': 0.0,
#  'request_id': '750bd630-9fa3-41f9-a99d-780e6942e3b1'}

# %%
output = format_search_query_results(docs, max_tokens=500, include_raw_content=True)

# %%
print(output)
# Out:
# Content from web search:
#
# Source What is LangGraph?:
# ===
# URL: https://www.ibm.com/think/topics/langgraph
# ===
# Most relevant content from source: # What is LangGraph?
#
# ## LangGraph overview
#
# LangGraph, created by LangChain, is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize large language models (LLMs) in a scalable and efficient manner. At its core, LangGraph uses the power of graph-based architectures to model and manage the intricate relationships between various components of an AI agent workflow. [...] Debugging: The capabilities do not end with building a graph, debugging features are included to ensure the graph is accurate and reliable. LangGraph Studio, with its cutting-edge integrated development environment (IDE), helps visualize and debug LangGraph applications.
#
# ## Future developments
#
# Enhanced natural language processing (NLP): LangGraph will have more advanced NLP capabilities, allowing it to better understand natural language and provide more accurate responses.
#
# Improved machine learning: LangGraph will have improved machine learning capabilities, allowing it to learn and improve over time.
#
# Support for new platforms: LangGraph will support new platforms, such as mobile devices and edge computing to make its technology more accessible.
#
# ## Authors [...] LangGraph is also built on several key technologies, including LangChain, a Python framework for building AI applications. LangChain includes a library for building and managing LLMs. LangGraph also uses the human-in-the-loop approach. By combining these technologies with a set of APIs and tools, LangGraph provides users with a versatile platform for developing AI solutions and workflows including chatbots, state graphs and other agent-based systems.
#
# Delve deeper into the world of LangGraph by exploring its key features, benefits and use cases. By the end of this article, you will have the knowledge and resources to take the next steps with LangGraph.
#
# ## Key components of LangGraph
# ===
# Raw Content: # What is LangGraph?
#
# ## LangGraph overview
#
# LangGraph, created by [LangChain](https://www.ibm.com/think/topics/langchain), is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize [large language models](https://www.ibm.com/think/topics/large-language-models) (LLMs) in a scalable and efficient manner. At its core, LangGraph uses the power of graph-based architectures to model and manage the intricate relationships between various components of an [AI agent workflow](https://www.ibm.com/think/topics/ai-agents).
#
# What does all this information mean? The following example can offer a clearer understanding of LangGraph: Think about these graph-based architectures as a powerful configurable map, a “Super-Map.” Users can envision the [AI workflow](https://www.ibm.com/think/topics/ai-workflow) as being “The Navigator” of this “Super-Map.” Finally, in this example, the user is “The Cartographer.” In this sense, the navigator charts out the optimal routes between points on the “Super-Map,” all of which are created by “The Cartographer.”
#
# To recap, optimal routes within the graph-based architectures (“Super-Map”) are charted and explored by using the AI workflow (“The Navigator”). This analogy is a great place to start understanding LangGraph—and if you like maps then you are welcome for the bonus opportunity to see someone use the word cartographer.
#
# ![LangGraph workflow](https://assets.ibm.com/is/image/ibm/langgraph?ts=1775068253616&dpr=off)
#
# LangGraph illuminates the processes within an AI workflow, allowing full transparency of the agent’s state. Within LangGraph, the “state” feature serves as a memory bank that records and tracks all the valuable information processed by the AI system. It’s similar to a digital notebook where the system captures and updates data as it moves through various stages of a workflow or graph analysis.
#
#
# Source LangGraph overview - Docs by LangChain:
# ===
# URL: https://docs.langchain.com/oss/python/langgraph/overview
# ===
# Most relevant content from source: LangGraph provides low-level supporting infrastructure for _any_ long-running, stateful workflow or agent. LangGraph does not abstract prompts or architecture, and provides the following central benefits:
#    Persistence: Build agents that persist through failures and can run for extended periods, resuming from where they left off.
#    Human-in-the-loop: Incorporate human oversight by inspecting and modifying agent state at any point.
#    Comprehensive memory: Create stateful agents with both short-term working memory for ongoing reasoning and long-term memory across sessions.
#    Debugging with LangSmith: Gain deep visibility into complex agent behavior with visualization tools that trace execution paths, capture state transitions, and provide detailed runtime metrics. [...] Trusted by companies shaping the future of agents— including Klarna, Uber, J.P. Morgan, and more— LangGraph is a low-level orchestration framework and runtime for building, managing, and deploying long-running, stateful agents.LangGraph is very low-level, and focused entirely on agent orchestration. Before using LangGraph, we recommend you familiarize yourself with some of the components used to build agents, starting with models and tools.We will commonly use LangChain components throughout the documentation to integrate models and tools, but you don’t need to use LangChain to use LangGraph. If you are just getting started with agents or want a higher-level abstraction, we recommend you use LangChain’s agents that provide prebuilt architectures for common LLM and tool-calling [...] prebuilt architectures for common LLM and tool-calling loops.LangGraph is focused on the underlying capabilities important for agent orchestration: durable execution, streaming, human-in-the-loop, and more.
# ===
# Raw Content: # LangGraph overview - Docs by LangChain
#
# [Skip to main content](https://docs.langchain.com/oss/python/langgraph/overview#content-area)
#
# [Docs by LangChain home page![Image 1: light logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://docs.langchain.com/)![Image 3: https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)Open source
#
# Search...
#
# Ctrl K
#
# *   [Ask AI](https://chat.langchain.com/)
# *   [GitHub](https://github.com/langchain-ai)
# *   [Try LangSmith](https://smith.langchain.com/)
# *   [Try LangSmith](https://smith.langchain.com/)
#
# Search...
#
# Navigation
#
# LangGraph overview
#
# [Deep Agents](https://docs.langchain.com/oss/python/deepagents/overview)[LangChain](https://docs.langchain.com/oss/python/langchain/overview)[LangGraph](https://docs.langchain.com/oss/python/langgraph/overview)[Integrations](https://docs.langchain.com/oss/python/integrations/providers/overview)[Learn](https://docs.langchain.com/oss/python/learn)[Reference](https://docs.langchain.com/oss/python/reference/overview)[Contribute](https://docs.langchain.com/oss/python/contributing/overview)
#
# Python
#
# *   [Overview](https://docs.langchain.com/oss/python/langgraph/overview)
#
# ### Get started
#
# *   [Install](https://docs.langchain.com/oss/python/langgraph/install)
# *   [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart)
# *   [Local server](https://docs.langchain.com/oss/python/langgraph/local-server)
# *   [Changelog](https://docs.langchain.com/oss/python/releases/changelog)
# *   [Thinking in LangGraph](https://docs.langc
#
# Source LangChain vs. LangGraph: A Developer's Guide to Choosing Your ...:
# ===
# URL: https://duplocloud.com/blog/langchain-vs-langgraph
# ===
# Most relevant content from source: LangGraph: LangGraph takes an explicit approach to state management. You define a state object (like a Python dictionary or TypedDict) that gets updated as the workflow progresses. Each node can read and modify this state. This gives you granular control. It’s important for long-running applications or multi-agent systems where you need to persist data. These can include conversation history or task lists across sessions. LangGraph also supports checkpointers for short- and long-term memory. This makes it ideal for stateful applications.
#
# Example: In the LangGraph task management example above, the TaskState object persists the task list across interactions, allowing the assistant to “remember” previous tasks. [...] from langchain.chains import LLMChain
#
# # Define a prompt and chain
#
# prompt = PromptTemplate(input\_variables=[“question”], template=”Answer this: {question}”)
#
# llm = OpenAI(model\_name=”gpt-3.5-turbo”)
#
# chain = LLMChain(llm=llm, prompt=prompt)
#
# # Run the chain
#
# result = chain.run(“What’s the capital of France?”)
#
# print(result)  # Output: The capital of France is Paris.
#
# This is LangChain’s bread and butter: a straightforward, sequential flow that’s easy to set up and debug.
#
# LangGraph: Now, imagine a flowchart where tasks can:
#
#  Loop back
#  Branch out
#  Talk to each other like a team of AI agents
#
# That’s what you’ll get with LangGraph. It’s a framework that models workflows as cyclical graphs with nodes (tasks) and edges (data flow or transitions). Each node can be an: [...] LangGraph: LangGraph is the maestro of dynamic, non-linear workflows. It’s specifically designed for scenarios where tasks might loop back. For example, a task management assistant might need to revisit previous tasks or handle conditional logic (“if the user says X, do Y”). They may also need to coordinate multiple agents (e.g., one for task creation, another for summarization). LangGraph’s graph structure makes this a breeze because it supports cycles and stateful interactions.
#
# Key Difference: LangChain is ideal for predictable, step-by-step processes. LangGraph handles complex, iterative, and multi-agent workflows with ease.
#
# 3. State Management: Implicit vs. Explicit
# ===
# Raw Content: [![Logo](https://duplocloud.com/wp-content/uploads/2025/11/header-logo.svg)](https://duplocloud.com) [![Logo](https://duplocloud.com/wp-content/uploads/2025/11/header-logo-black.svg)](https://duplocloud.com)
#
# [See Demo](https://duplocloud.com/request-a-demo)
#
#   [Skip to content](#primary)
#
# # LangChain vs. LangGraph: A Developer’s Guide to Choosing Your AI Workflow
#
# Author: Joel Lim
#
# Here at DuploCloud, we’ve been navigating the tumultuous waters of AI in an effort to champion its use in automating DevOps workflows (and make using it simpler).
#
# This has brought us face-to-face with some big questions about architectural components of AI-driven systems, such as LangChain vs. LangGraph. Let’s take a look.
#
# Both **LangChain** and **LangGraph** are open-source frameworks from the LangChain ecosystem that sound similar but play very different roles in the AI orchestra. Whether you’re a non-technical dreamer or a code-slinging developer, this article breaks down the differences with a sprinkle of fun and a lot of technical meat. Let’s dive in!
#
# ## **Key Takeaways**
#
# 1. LangChain is best for linear, modular AI workflows that call for a quick setup and minimal complexity, so it’s ideal for prototypes, simple chatbots, and RAG pipelines.
# 2. LangGraph excels in building complex, stateful, and multi-agent systems thanks to its graph-based architecture, explicit state management, and real-time streaming capabilities.
# 3. LangGraph and LangChain can be used together, which lets developers combine the simplicity of chains with the power of dynamic graphs for robust AI applications.
#
# **For Non-Technical People: The Quick Scoop**
#
# Picture LangChain as a trusty Swiss Army knife for building AI apps. It’s great for straightforward tasks like:
#
# * Fetching data
# * Summarizing it
# * Answering questions
#
# And it can do it in a neat, step-by-step flow. Think of it as a conveyor belt. You put the data in, it gets processed, and then it comes out nice and shiny.
#
# **It’s easy to use, and it’s pe
#
# Source What is LangGraph - GeeksforGeeks:
# ===
# URL: https://www.geeksforgeeks.org/machine-learning/what-is-langgraph
# ===
# Most relevant content from source: geeksforgeeks
#
# # What is LangGraph
#
# LangGraph is an open-source framework from LangChain designed to build and manage AI agent workflows using graph-based structures. It allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable and easier to control.
#
# langchain_vs_langgraph_pipelines
#
# LangChain uses a straightforward step-by-step pipeline where each task follows a fixed sequence from input to output while LangGraph allows flexible workflows with branching and parallel steps, making it better suited for complex, decision-based applications.
#
# ## Workflow of LangGraph
#
# The diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.
#
# what_is_langgraph_ [...] if classification == "greeting":
#         response = "Hello! How can I help you today?"
#     elif classification == "search":
#         response = ask_gemini(question)
#     else:
#         response = "I'm not sure how to respond to that."
#
#     return {
#         state,
#         "response": response
#     }
#
# ````
#
# ### Step 6: Build LangGraph Workflow
#
# ````
# import networkx as nx
# import matplotlib.pyplot as plt
# from langgraph.graph import StateGraph
#
# builder = StateGraph(GraphState)
# builder.add_node("classify", classify)
# builder.add_node("respond", respond)
# builder.set_entry_point("classify")
# builder.add_edge("classify", "respond")
# builder.set_finish_point("respond")
# app = builder.compile()
#
# def visualize_workflow(builder):
#     G = nx.DiGraph() [...] def visualize_workflow(builder):
#     G = nx.DiGraph()
#
#     for node in builder.nodes:
#         G.add_node(node)
#     for edge in builder.edges:
#         G.add_edge(edge, edge)
#
#     pos = nx.spring_layout(G)
#     nx.draw(G, pos, with_labels=True, node_size=3000,
#             node_color="skyblue", font_size=12, font_weight="bold", arrows=True)
#
#     plt.title("Langchain Workflow Visualization")
#     plt.show()
#
# visualize_workflow(builder)
#
# ````
#
# Output:
#
# LangGraph
#
# ### Step 7: Interactive Chat Interface
#
# ````
# print("=== Gemini-Powered Chatbot ===")
# print("Type your question below. Type 'exit' to quit.\n")
#
# while True:
#     user_input = input("You: ")
#     if user_input.strip().lower() in ['exit', 'quit']:
#         print("Bot: Goodbye!")
#         break
# ===
# Raw Content: ![geeksforgeeks](https://media.geeksforgeeks.org/gfg-gg-logo.svg)
#
# # What is LangGraph
#
# LangGraph is an open-source framework from LangChain designed to build and manage AI agent workflows using graph-based structures. It allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable and easier to control.
#
# ![langchain_vs_langgraph_pipelines](https://media.geeksforgeeks.org/wp-content/uploads/20260320152116700448/langchain_vs_langgraph_pipelines.webp)
#
# LangChain uses a straightforward step-by-step pipeline where each task follows a fixed sequence from input to output while LangGraph allows flexible workflows with branching and parallel steps, making it better suited for complex, decision-based applications.
#
# ## Workflow of LangGraph
#
# The diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.
#
# ![what_is_langgraph_](https://media.geeksforgeeks.org/wp-content/uploads/20251212160007527277/what_is_langgraph_.webp)
#
# Here's a step by step interpretation of the flow:
#
# ## Components
#
# These core components work together smoothly to help developers build, customize and manage complex AI driven workflows.
#
# ## How LangGraph Scales
#
# ## Building a Simple Chatbot with LangGraph
#
# LangGraph makes it easy to build structured, stateful applications like chatbots. In this example we’ll learn how to create a basic chatbot that can classify user input as either a greet, search query and respond accordingly.
#
# ### Step 1: Install the Dependencies
#
# Installs the required dependencies,
#
# ````
# !pip install langgraph langchain google-generativeai
#
# ````
#
# ### Step 2: Setup Gemini API
#
# To know how to access Gemini API refer to : [How to Access and Use Google Gemini API Key (with Examples)](https://www.geeksforgeeks.org/artificial-intelligence/how-to-use-google-gemini-api-key/)
#
# ````
# import google.generativeai as genai
#
# genai.configure(api_key="YOUR_API_KEY")
#
# model = genai.GenerativeModel("gemini-1
#
# Source Understanding LangGraph Data Visualization Software | Coursera:
# ===
# URL: https://www.coursera.org/articles/langgraph
# ===
# Most relevant content from source: ## What is LangGraph?
#
# LangGraph is an open-source library within the LangChain ecosystem that enables developers to build multi-agent applications using large language models (LLMs). While traditional AI workflows are often linear and rigid, LangGraph uses graph-based architectures to manage complex relationships between components. LangGraph provides a flexible way to coordinate and execute multiple LLM “agents” in complex workflows; by using "cycles" and "state management", it allows AI agents to solve large-scale problems that require iterative reasoning and human-like step-by-step logic.
#
# ## 3 key features of LangGraph
#
# 1. Graph-based Structure: Retains information across stages, making it easy to add conditional steps or "memory" to a chatbot.
# ===
# Raw Content: # Understanding LangGraph Data Visualization Software
#
# Written by Coursera Staff • Updated on
#
# Discover how LangGraph enhances NLP by transforming text into structured visual graphs. Learn its key features, real-world applications, and best practices to optimize AI workflows. Get started today with expert insights and practical resources.
#
# ![[Featured Image] Professionals collaborate on a project and discuss LangGraph with a laptop displaying an international sales graph.
# ](https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://images.ctfassets.net/wp1lcwdav1p1/3b1Ue0cPoLIoTVGKzSsgr0/4abb81dc392b7bfdc613b0f5c6c80f60/GettyImages-2064277143.jpg?w=1500&h=680&q=60&fit=fill&f=faces&fm=jpg&fl=progressive&auto=format%2Ccompress&dpr=1&w=1000)
#
# ## Key Takeaways
#
# LangGraph is a specialized open-source framework within the LangChain ecosystem designed to build and manage multi-agent applications and complex AI workflows using large language models.
#
# * LangGraph enables developers to coordinate and execute multiple LLM agents through graph-based architectures that introduce robust state management and conditional logic.
#
# * This cyclical framework allows workflows to retain information across different stages, remember previous inputs, and adjust behavior based on real-time data.
#
# * You can explore the official LangChain documentation and tutorials to familiarize yourself with key features and build full-fledged chatbots.
#
# Read on to learn more about LangGraph, including its key features, real-world industry applications, and best practices for development. Build job-ready skills for an in-demand career by enrolling in the IBM AI Engineering Professional Certificate.
#
# ## **What is LangGraph?**
#
# LangGraph is an open-source library within the LangChain ecosystem that enables developers to build multi-agent applications using large language models ([LLMs](https://www.coursera.org/articles/large-language-models)). While traditional AI workflows are often linear an

# %% [markdown]
# ## Default Report Template
#
# This is the starting point for the LLM to get an idea of how to build a general report and it will use this to build a custom report structure

# %%
# Structure
DEFAULT_REPORT_STRUCTURE = """The report structure should focus on breaking-down the user-provided topic
                              and building a comprehensive report in markdown using the following format:

                              1. Introduction (no web search needed)
                                    - Brief overview of the topic area

                              2. Main Body Sections:
                                    - Each section should focus on a sub-topic of the user-provided topic
                                    - Include any key concepts and definitions
                                    - Provide real-world examples or case studies where applicable

                              3. Conclusion (no web search needed)
                                    - Aim for 1 structural element (either a list of table) that distills the main body sections
                                    - Provide a concise summary of the report

                              When generating the final response in markdown, if there are special characters in the text,
                              such as the dollar symbol, ensure they are escaped properly for correct rendering e.g $25.5 should become \\$25.5
                          """

# %% [markdown]
# ## Instruction Prompts for Report Planner
#
# There are two main instruction prompts:
#
# - __REPORT_PLAN_QUERY_GENERATOR_PROMPT:__ Helps the LLM to generate an initial list of questions based on the topic to get more information from the web about that topic so that it can plan the overall sections and structure of the report
#
# - __REPORT_PLAN_SECTION_GENERATOR_PROMPT:__ Here we feed the LLM with the default report template, the topic name and the search results from the intial queries generated to create a detailed structure for the report. The LLM will generate a structured response of the following fields for each major section which will be in the report (this is just the report structure - no content is created at this step):
#     - Name - Name for this section of the report.
#     - Description - Brief overview of the main topics and concepts to be covered in this section.
#     - Research - Whether to perform web search for this section of the report or not.
#     - Content - The content of the section, which you will leave blank for now.

# %%
REPORT_PLAN_QUERY_GENERATOR_PROMPT = """You are an expert technical report writer, helping to plan a report.

The report will be focused on the following topic:
{topic}

The report structure will follow these guidelines:
{report_organization}

Your goal is to generate {number_of_queries} search queries that will help gather comprehensive information for planning the report sections.

The query should:
1. Be related to the topic
2. Help satisfy the requirements specified in the report organization

Make the query specific enough to find high-quality, relevant sources while covering the depth and breadth needed for the report structure.
"""

# %%
REPORT_PLAN_SECTION_GENERATOR_PROMPT = """You are an expert technical report writer, helping to plan a report.

Your goal is to generate the outline of the sections of the report.

The overall topic of the report is:
{topic}

The report should follow this organizational structure:
{report_organization}

You should reflect on this additional context information from web searches to plan the main sections of the report:
{search_context}

Now, generate the sections of the report. Each section should have the following fields:
- Name - Name for this section of the report.
- Description - Brief overview of the main topics and concepts to be covered in this section.
- Research - Whether to perform web search for this section of the report or not.
- Content - The content of the section, which you will leave blank for now.

Consider which sections require web search.
For example, introduction and conclusion will not require research because they will distill information from other parts of the report.
"""

# %% [markdown]
# ## Node Function for Report Planner
#
# ![](/Users/sachinmishra/Desktop/Agents_From_Scratch/Experiments/report_planning_phase.svg)
#
# This function uses the two prompts created above to:
#  - First generate some queries based on the user topic
#  - Search the web and get some information on these queries
#  - Use this information to generate the overall structure of the report with the key sections necessary to be created

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite", temperature=0)

async def generate_report_plan(state: ReportState):
    """Generate the overall plan for building the report"""
    topic = state["topic"]
    print('--- Generating Report Plan ---')

    report_structure = DEFAULT_REPORT_STRUCTURE
    number_of_queries = 4

    structured_llm = llm.with_structured_output(Queries)

    system_instructions_query = REPORT_PLAN_QUERY_GENERATOR_PROMPT.format(
        topic=topic,
        report_organization=report_structure,
        number_of_queries=number_of_queries
    )

    try:
        # Generate queries
        results = structured_llm.invoke([
            SystemMessage(content=system_instructions_query),
            HumanMessage(content='Generate search queries that will help with planning the sections of the report.')
        ])

        # Convert SearchQuery objects to strings
        query_list = [
            query.search_query if isinstance(query, SearchQuery) else str(query)
            for query in results.queries
        ]

        # Search web and ensure we wait for results
        search_docs = await run_search_queries(
            query_list,
            num_results=4,
            include_raw_content=False
        )

        if not search_docs:
            print("Warning: No search results returned")
            search_context = "No search results available."
        else:
            search_context = format_search_query_results(
                search_docs,
                include_raw_content=False
            )

        # Generate sections
        system_instructions_sections = REPORT_PLAN_SECTION_GENERATOR_PROMPT.format(
            topic=topic,
            report_organization=report_structure,
            search_context=search_context
        )

        structured_llm = llm.with_structured_output(Sections)
        report_sections = structured_llm.invoke([
            SystemMessage(content=system_instructions_sections),
            HumanMessage(content="Generate the sections of the report. Your response must include a 'sections' field containing a list of sections. Each section must have: name, description, plan, research, and content fields.")
        ])

        print('--- Generating Report Plan Completed ---')
        return {"sections": report_sections.sections}

    except Exception as e:
        print(f"Error in generate_report_plan: {e}")
        return {"sections": []}

# %% [markdown]
# ## Instruction Prompts for Section Builder - Query Generator
#
# There is one main instruction prompt:
#
# - __REPORT_SECTION_QUERY_GENERATOR_PROMPT:__ Helps the LLM to generate a comprehensive list of questions for the topic of that specific section which needs to be built

# %%
REPORT_SECTION_QUERY_GENERATOR_PROMPT = """Your goal is to generate targeted web search queries that will gather comprehensive information for writing a technical report section.

Topic for this section:
{section_topic}

When generating {number_of_queries} search queries, ensure that they:
1. Cover different aspects of the topic (e.g., core features, real-world applications, technical architecture)
2. Include specific technical terms related to the topic
3. Target recent information by including year markers where relevant (e.g., "2024")
4. Look for comparisons or differentiators from similar technologies/approaches
5. Search for both official documentation and practical implementation examples

Your queries should be:
- Specific enough to avoid generic results
- Technical enough to capture detailed implementation information
- Diverse enough to cover all aspects of the section plan
- Focused on authoritative sources (documentation, technical blogs, academic papers)"""

# %% [markdown]
# ## Node Function for Section Builder - Generate Queries (Query Generator)
#
# This uses the section topic and the instruction prompt above to generate some questions for researching on the web for getting useful information on the section topic

# %%
def generate_queries(state: SectionState):
    """ Generate search queries for a specific report section """



    # Get state
    section = state["section"]
    print('--- Generating Search Queries for Section: '+ section.name +' ---')

    # Get configuration
    number_of_queries = 4

    # Generate queries
    structured_llm = llm.with_structured_output(Queries)

    # Format system instructions
    system_instructions = REPORT_SECTION_QUERY_GENERATOR_PROMPT.format(section_topic=section.description,
                                                                       number_of_queries=number_of_queries)

    # Generate queries
    user_instruction = "Generate search queries on the provided topic."
    search_queries = structured_llm.invoke([SystemMessage(content=system_instructions),
                                     HumanMessage(content=user_instruction)])

    print('--- Generating Search Queries for Section: '+ section.name +' Completed ---')

    return {"search_queries": search_queries.queries}

# %% [markdown]
# ## Node Function for Section Builder - Search Web
#
# Takes the queries generated by `generate_queries(...)`for a specific section, searches the web and formats the search results using the utility functions we defined earlier

# %%
async def search_web(state: SectionState):
    """ Search the web for each query, then return a list of raw sources and a formatted string of sources."""

    # Get state
    search_queries = state["search_queries"]

    print('--- Searching Web for Queries ---')

    # Web search
    query_list = [query.search_query for query in search_queries]
    search_docs = await run_search_queries(search_queries, num_results=4, include_raw_content=True)

    # Deduplicate and format sources
    search_context = format_search_query_results(search_docs, max_tokens=4000, include_raw_content=True)

    print('--- Searching Web for Queries Completed ---')

    return {"source_str": search_context}

# %% [markdown]
# ## Instruction Prompts for Section Builder - Section Writer
#
# There is one main instruction prompt:
#
# - __SECTION_WRITER_PROMPT:__ Constrains the LLM to generate and write the content for a specific section using certain guidelines on style, structure, length, approach and the documents obtained from the web earlier using the `search_web(...)` function are also sent.

# %%
SECTION_WRITER_PROMPT = """You are an expert technical writer crafting one specific section of a technical report.

Title for the section:
{section_title}

Topic for this section:
{section_topic}

Guidelines for writing:

1. Technical Accuracy:
- Include specific version numbers
- Reference concrete metrics/benchmarks
- Cite official documentation
- Use technical terminology precisely

2. Length and Style:
- Strict 150-200 word limit
- No marketing language
- Technical focus
- Write in simple, clear language do not use complex words unnecessarily
- Start with your most important insight in **bold**
- Use short paragraphs (2-3 sentences max)

3. Structure:
- Use ## for section title (Markdown format)
- Only use ONE structural element IF it helps clarify your point:
  * Either a focused table comparing 2-3 key items (using Markdown table syntax)
  * Or a short list (3-5 items) using proper Markdown list syntax:
    - Use `*` or `-` for unordered lists
    - Use `1.` for ordered lists
    - Ensure proper indentation and spacing
- End with ### Sources that references the below source material formatted as:
  * List each source with title, date, and URL
  * Format: `- Title : URL`

3. Writing Approach:
- Include at least one specific example or case study if available
- Use concrete details over general statements
- Make every word count
- No preamble prior to creating the section content
- Focus on your single most important point

4. Use this source material obtained from web searches to help write the section:
{context}

5. Quality Checks:
- Format should be Markdown
- Exactly 150-200 words (excluding title and sources)
- Careful use of only ONE structural element (table or bullet list) and only if it helps clarify your point
- One specific example / case study if available
- Starts with bold insight
- No preamble prior to creating the section content
- Sources cited at end
- If there are special characters in the text, such as the dollar symbol,
  ensure they are escaped properly for correct rendering e.g $25.5 should become \\$25.5
"""

# %% [markdown]
# ## Node Function for Section Builder - Write Section (Section Writer)
#
# Uses the SECTION_WRITER_PROMPT from above and feeds it with the section name, description and web search documents and passes it to an LLM to write the content for that section

# %%
def write_section(state: SectionState):
    """ Write a section of the report """

    # Get state
    section = state["section"]
    source_str = state["source_str"]

    print('--- Writing Section : '+ section.name +' ---')

    # Format system instructions
    system_instructions = SECTION_WRITER_PROMPT.format(section_title=section.name,
                                                       section_topic=section.description,
                                                       context=source_str)

    # Generate section
    user_instruction = "Generate a report section based on the provided sources."
    section_content = llm.invoke([SystemMessage(content=system_instructions),
                                  HumanMessage(content=user_instruction)])

    # Extract text content from response (handle both string and structured formats)
    if isinstance(section_content.content, str):
        content_text = section_content.content
    elif isinstance(section_content.content, list):
        # Extract text from list of content blocks
        content_text = "".join([block.get('text', '') if isinstance(block, dict) else str(block) for block in section_content.content])
    else:
        content_text = str(section_content.content)
    
    # Write content to the section object
    section.content = content_text

    print('--- Writing Section : '+ section.name +' Completed ---')

    # Write the updated section to completed sections
    return {"completed_sections": [section]}

# %% [markdown]
# ## Create the Section Builder Sub-Agent
#
# ![](https://i.imgur.com/5VEYGrQ.png)
#
# This agent (or to be more specific, sub-agent) will be called several times in parallel, once for each section to search the web, get content and then write up that specific section

# %%
from langgraph.graph import StateGraph, START, END

# Add nodes and edges
section_builder = StateGraph(SectionState, output_schema=SectionOutputState)
section_builder.add_node("generate_queries", generate_queries)
section_builder.add_node("search_web", search_web)
section_builder.add_node("write_section", write_section)

section_builder.add_edge(START, "generate_queries")
section_builder.add_edge("generate_queries", "search_web")
section_builder.add_edge("search_web", "write_section")
section_builder.add_edge("write_section", END)
section_builder_subagent = section_builder.compile()

# %%
# Display the graph
from IPython.display import display, Image
Image(section_builder_subagent.get_graph().draw_mermaid_png())

# %% [markdown]
# ### Create Dynamic Parallelization Node Function - Parallelize Section Writing
#
# `Send(...)` is used to parallelize and call the `section_builder_subagent` once for each section to write up the content (in parallel)

# %%
from langgraph.types import Send

def parallelize_section_writing(state: ReportState):
    """ This is the "map" step when we kick off web research for some sections of the report in parallel and then write the section"""

    # Kick off section writing in parallel via Send() API for any sections that require research
    return [
        Send("section_builder_with_web_search", # name of the subagent node
             {"section": s})
            for s in state["sections"]
              if s.research
    ]

# %% [markdown]
# ## Create Format Sections Node Function
#
# This is basically the section where all the sections are formatted and combined together into one big document.
#
# ![](https://i.imgur.com/6e5ZWK4.png)

# %%
def format_sections(sections: list[Section]) -> str:
    """ Format a list of report sections into a single text string """
    formatted_str = ""
    for idx, section in enumerate(sections, 1):
        formatted_str += f"""
{'='*60}
Section {idx}: {section.name}
{'='*60}
Description:
{section.description}
Requires Research:
{section.research}

Content:
{section.content if section.content else '[Not yet written]'}

"""
    return formatted_str


def format_completed_sections(state: ReportState):
    """ Gather completed sections from research and format them as context for writing the final sections """

    print('--- Formatting Completed Sections ---')

    # List of completed sections
    completed_sections = state["completed_sections"]

    # Format completed section to str to use as context for final sections
    completed_report_sections = format_sections(completed_sections)

    print('--- Formatting Completed Sections is Done ---')

    return {"report_sections_from_research": completed_report_sections}

# %% [markdown]
# ## Instruction Prompts for Final Section
#
# There is one main instruction prompt:
#
# - __FINAL_SECTION_WRITER_PROMPT:__ Constrains the LLM to generate and write the content for either the introduction OR conclusion using certain guidelines on style, structure, length, approach and the content of the already written sections are also sent.

# %%
FINAL_SECTION_WRITER_PROMPT = """You are an expert technical writer crafting a section that synthesizes information from the rest of the report.

Title for the section:
{section_title}

Topic for this section:
{section_topic}

Available report content of already completed sections:
{context}

1. Section-Specific Approach:

For Introduction:
- Use # for report title (Markdown format)
- 50-100 word limit
- Write in simple and clear language
- Focus on the core motivation for the report in 1-2 paragraphs
- Use a clear narrative arc to introduce the report
- Include NO structural elements (no lists or tables)
- No sources section needed

For Conclusion/Summary:
- Use ## for section title (Markdown format)
- 100-150 word limit
- For comparative reports:
    * Must include a focused comparison table using Markdown table syntax
    * Table should distill insights from the report
    * Keep table entries clear and concise
- For non-comparative reports:
    * Only use ONE structural element IF it helps distill the points made in the report:
    * Either a focused table comparing items present in the report (using Markdown table syntax)
    * Or a short list using proper Markdown list syntax:
      - Use `*` or `-` for unordered lists
      - Use `1.` for ordered lists
      - Ensure proper indentation and spacing
- End with specific next steps or implications
- No sources section needed

3. Writing Approach:
- Use concrete details over general statements
- Make every word count
- Focus on your single most important point

4. Quality Checks:
- For introduction: 50-100 word limit, # for report title, no structural elements, no sources section
- For conclusion: 100-150 word limit, ## for section title, only ONE structural element at most, no sources section
- Markdown format
- Do not include word count or any preamble in your response
- If there are special characters in the text, such as the dollar symbol,
  ensure they are escaped properly for correct rendering e.g $25.5 should become \\$25.5"""

# %% [markdown]
# ## Create Write Final Sections Node Function
#
# This function uses the instruction prompot FINAL_SECTION_WRITER_PROMPT mentioned above to write up the introduction and conclusion. This function will be executed in parallel using `Send(...)` below
#
# ![](https://i.imgur.com/pRv4PX8.png)

# %%
def write_final_sections(state: SectionState):
    """ Write the final sections of the report, which do not require web search and use the completed sections as context"""

    # Get state
    section = state["section"]
    completed_report_sections = state["report_sections_from_research"]

    print('--- Writing Final Section: '+ section.name + ' ---')

    # Format system instructions
    system_instructions = FINAL_SECTION_WRITER_PROMPT.format(section_title=section.name,
                                                             section_topic=section.description,
                                                             context=completed_report_sections)

    # Generate section
    user_instruction = "Craft a report section based on the provided sources."
    section_content = llm.invoke([SystemMessage(content=system_instructions),
                                  HumanMessage(content=user_instruction)])

    # Extract text content from response (handle both string and structured formats)
    if isinstance(section_content.content, str):
        content_text = section_content.content
    elif isinstance(section_content.content, list):
        # Extract text from list of content blocks
        content_text = "".join([block.get('text', '') if isinstance(block, dict) else str(block) for block in section_content.content])
    else:
        content_text = str(section_content.content)
    
    # Write content to section
    section.content = content_text

    print('--- Writing Final Section: '+ section.name + ' Completed ---')

    # Write the updated section to completed sections
    return {"completed_sections": [section]}

# %% [markdown]
# ### Create Dynamic Parallelization Node Function - Parallelize Final Section Writing
#
# `Send(...)` is used to parallelize and call the `write_final_sections` once for each of the introduction and conclusion to write up the content (in parallel)

# %%
from langgraph.types import Send

def parallelize_final_section_writing(state: ReportState):
    """ Write any final sections using the Send API to parallelize the process """

    # Kick off section writing in parallel via Send() API for any sections that do not require research
    return [
        Send("write_final_sections",
             {"section": s, "report_sections_from_research": state["report_sections_from_research"]})
                 for s in state["sections"]
                    if not s.research
    ]

# %% [markdown]
# ## Compile Final Report Node Function
#
# This function combines all the sections of the report together and compiles it into the final report document
#
# ![](https://i.imgur.com/wLxCNZ5.png)

# %%
def compile_final_report(state: ReportState):
    """ Compile the final report """

    # Get sections
    sections = state["sections"]
    completed_sections = {s.name: s.content for s in state["completed_sections"]}

    print('--- Compiling Final Report ---')

    # Update sections with completed content while maintaining original order
    for section in sections:
        section.content = completed_sections[section.name]

    # Compile final report - ensure all content is string before joining
    all_sections = "\n\n".join([
        str(s.content) if not isinstance(s.content, str) else s.content 
        for s in sections
    ])
    
    # Escape unescaped $ symbols to display properly in Markdown
    formatted_sections = all_sections.replace("\\$", "TEMP_PLACEHOLDER")  # Temporarily mark already escaped $
    formatted_sections = formatted_sections.replace("$", "\\$")  # Escape all $
    formatted_sections = formatted_sections.replace("TEMP_PLACEHOLDER", "\\$")  # Restore originally escaped $

    print('--- Compiling Final Report Done ---')

    return {"final_report": formatted_sections}

# %% [markdown]
# ## Build our Report Writer Planning Agent
#
# We now bring all the defined components and sub-agent together and build our planning agent
#
# ![](/Users/sachinmishra/Desktop/Agents_From_Scratch/Experiments/report_generation_flow.svg)

# %%
builder = StateGraph(ReportState, input_schema=ReportStateInput, output_schema=ReportStateOutput)

builder.add_node("generate_report_plan", generate_report_plan)
builder.add_node("section_builder_with_web_search", section_builder_subagent)
builder.add_node("format_completed_sections", format_completed_sections)
builder.add_node("write_final_sections", write_final_sections)
builder.add_node("compile_final_report", compile_final_report)

builder.add_edge(START, "generate_report_plan")
builder.add_conditional_edges("generate_report_plan",
                              parallelize_section_writing,
                              ["section_builder_with_web_search"])
builder.add_edge("section_builder_with_web_search", "format_completed_sections")
builder.add_conditional_edges("format_completed_sections",
                              parallelize_final_section_writing,
                              ["write_final_sections"])
builder.add_edge("write_final_sections", "compile_final_report")
builder.add_edge("compile_final_report", END)

reporter_agent = builder.compile()

# %%
display(Image(reporter_agent.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# ## Run and Test our Agent

# %%
from IPython.display import display
from rich.console import Console
from rich.markdown import Markdown as RichMarkdown

async def call_planner_agent(agent, prompt, config={"recursion_limit": 50}, verbose=False):
    events = agent.astream(
        {'topic' : prompt},
        config,
        stream_mode="values",
    )

    async for event in events:
        for k, v in event.items():
            if verbose:
                if k != "__end__":
                    display(RichMarkdown(repr(k) + ' -> ' + repr(v)))
            if k == 'final_report':
                print('='*50)
                print('Final Report:')
                md = RichMarkdown(v)
                display(md)

# %%
topic = "Detailed report on how to build Agentic AI systems, design patterns and current frameworks"
await call_planner_agent(agent=reporter_agent,
                         prompt=topic)
# Out:
# --- Generating Report Plan ---
# --- Generating Report Plan Completed ---
# --- Generating Search Queries for Section: Core Components of Agentic AI ---
# --- Generating Search Queries for Section: Agentic Design Patterns ---
# --- Generating Search Queries for Section: Frameworks and Orchestration ---
# --- Generating Search Queries for Section: Enterprise Implementation and Governance ---
# --- Generating Search Queries for Section: Core Components of Agentic AI Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Agentic Design Patterns Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Enterprise Implementation and Governance Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Frameworks and Orchestration Completed ---
# --- Searching Web for Queries ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Frameworks and Orchestration ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Agentic Design Patterns ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Core Components of Agentic AI ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Enterprise Implementation and Governance ---
# --- Writing Section : Frameworks and Orchestration Completed ---
# --- Writing Section : Agentic Design Patterns Completed ---
# --- Writing Section : Core Components of Agentic AI Completed ---
# --- Writing Section : Enterprise Implementation and Governance Completed ---
# --- Formatting Completed Sections ---
# --- Formatting Completed Sections is Done ---
# --- Writing Final Section: Introduction ---
# --- Writing Final Section: Conclusion ---
# --- Writing Final Section: Introduction Completed ---
# --- Writing Final Section: Conclusion Completed ---
# --- Compiling Final Report ---
# --- Compiling Final Report Done ---
# ==================================================
# Final Report:
#                                                    Introduction
#
# The landscape of artificial intelligence is undergoing a fundamental transformation, shifting from passive,
# prompt-based interactions to autonomous, goal-driven systems known as Agentic AI. Unlike traditional chatbots that
# merely respond to user input, agentic systems utilize modular architectures—integrating reasoning, planning,
# memory, and tool use—to execute complex, multi-step workflows independently. This evolution enables AI to move
# beyond simple text generation into the realm of autonomous problem-solving. This report explores the architectural
# patterns, orchestration frameworks, and governance strategies necessary to transition these sophisticated systems
# from experimental prototypes into reliable, production-grade enterprise solutions.
#
# Core Components of Agentic AI
#
# Agentic AI systems derive their autonomy from a modular architecture that integrates reasoning, planning, memory,
# and tool use to execute complex, multi-step goals without constant human intervention. Unlike static automation,
# these systems dynamically adapt to changing environments by iterating through a "think-act-observe" loop.
#
# The fundamental pillars of these systems include:
#
#  • Reasoning: The engine that processes information and applies logic, often utilizing techniques like
#    Chain-of-Thought (CoT) or ReAct to decompose tasks.
#  • Planning: The ability to break high-level objectives into manageable sub-tasks, allowing for iterative execution
#    and course correction.
#  • Memory: A dual-layer system consisting of short-term context (e.g., conversation buffers) for immediate
#    coherence and long-term storage (e.g., vector databases) for persistent knowledge.
#  • Tool Use: The capacity to interface with external APIs, databases, or code interpreters to fetch real-time data
#    or perform actions.
#
# For example, in enterprise analytics, an agent might autonomously query a database, analyze trends, and draft a
# report. By leveraging frameworks like LangGraph or AutoGen, developers can orchestrate these components to build
# reliable, scalable systems that move beyond simple text generation into true autonomous problem-solving.
#
# Sources
#
#  • Agentic Design Patterns: A System-Theoretic Framework : https://arxiv.org/html/2601.19752v1
#  • What Is Agentic Reasoning? | IBM : https://www.ibm.com/think/topics/agentic-reasoning
#  • The Landscape of Emerging AI Agent Architectures : https://arxiv.org/html/2404.11584v1
#  • Agentic AI Architectures And Design Patterns :
#    https://medium.com/@anil.jain.baba/agentic-ai-architectures-and-design-patterns-288ac589179a
#
# Agentic Design Patterns
#
# Architectural patterns for AI agents prioritize reliability and governance by balancing autonomous reasoning with
# structured control. While simple ReAct loops (Reason + Act) offer dynamic adaptation, they often suffer from myopic
# decision-making and high token costs. Production-grade systems increasingly adopt more predictable blueprints to
# mitigate these risks.
#
#
#  Pattern           Primary Benefit          Best Use Case
#  ──────────────────────────────────────────────────────────────────────────────
#  ReAct             Dynamic adaptation       Exploratory research tasks
#  Plan-and-Execute  Reduced token usage      Structured, multi-step workflows
#  Reflection        Iterative quality gains  Code generation and data extraction
#
#
# Reflection patterns, such as Reflexion, improve performance by enabling agents to critique their own outputs,
# though this typically increases token consumption by 2-3x. For high-stakes environments, Human-in-the-loop (HITL)
# integration is essential. Frameworks like LangGraph provide built-in interrupts and approval gates, allowing agents
# to pause for human validation before executing critical actions. For example, healthcare systems use hierarchical
# agents for patient monitoring, where autonomous agents perform initial risk assessments, but human oversight
# remains mandatory for final intervention triggers. By combining these patterns with custom logic, developers can
# build governable systems that maintain safety without sacrificing the efficiency of autonomous reasoning.
#
# Sources
#
#  • AI Agent Architecture Patterns: Single & Multi-Agent Systems :
#    https://redis.io/blog/ai-agent-architecture-patterns
#  • Single-Agent Patterns: ReAct, Plan-and-Execute, ReWOO, and Reflexion :
#    https://theaiengineer.substack.com/p/the-4-single-agent-patterns
#  • Human-in-the-Loop in Agentic Workflows : https://orkes.io/blog/human-in-the-loop
#
# Frameworks and Orchestration
#
# LangGraph is the most production-ready framework for complex, stateful agentic systems. While frameworks like
# CrewAI and AutoGen offer rapid prototyping and conversational flexibility, they often struggle with the reliability
# and auditability required for mission-critical enterprise environments. LangGraph’s graph-based architecture treats
# workflows as state machines, providing explicit control over branching, loops, and error recovery. This
# deterministic approach is essential for systems where failure recovery and human-in-the-loop oversight are
# non-negotiable.
#
#
#  Feature       LangGraph                  CrewAI              AutoGen (AG2)
#  ───────────────────────────────────────────────────────────────────────────────────
#  Architecture  Graph-based (Nodes/Edges)  Role-based (Teams)  Conversation-driven
#  Best For      Production/Stateful        Prototyping/Roles   Research/Collaboration
#  Production    High (e.g., Klarna, Uber)  Moderate            Low (Research-heavy)
#
#
# For instance, Klarna successfully deployed a customer support agent using LangGraph, handling millions of
# interactions with high reliability. In contrast, AutoGen’s conversational loops can lead to unpredictable token
# costs and latency, making it better suited for research than for serving millions of users. For enterprises, the
# investment in LangGraph’s steeper learning curve is justified by its built-in checkpointing, durable execution, and
# seamless integration with observability tools like LangSmith.
#
# Sources
#
#  • CrewAI vs LangGraph vs AutoGen (2026 Comparison) : https://pickaxe.co/post/crewai-vs-langgraph-vs-autogen
#  • LangGraph vs CrewAI: Let's Learn About the Differences : https://www.zenml.io/blog/langgraph-vs-crewai
#  • LangGraph vs CrewAI vs AutoGen: Production Guide (2026) :
#    https://pub.towardsai.net/langgraph-vs-crewai-vs-autogen-which-ai-agent-framework-should-your-enterprise-use-in-
#    2026-3a9ebb407b09
#
# Enterprise Implementation and Governance
#
# Successful production deployment of AI agents requires shifting from passive monitoring to active, behavioral
# observability that treats agents as stateful, non-deterministic systems. Unlike traditional software, agents
# operate through multi-step reasoning chains where failures often manifest as logical drift rather than system
# crashes. Organizations must implement comprehensive distributed tracing to capture the full execution graph,
# including LLM reasoning steps, tool invocations, and memory operations.
#
# To ensure reliability, teams should adopt the following governance and operational practices:
#
#  • Deterministic Guardrails: Enforce security policies via infrastructure-level controls external to the agent’s
#    reasoning loop to prevent prompt injection and unauthorized tool access.
#  • Continuous Evaluation: Integrate automated "LLM-as-a-judge" evaluators into production pipelines to validate
#    output quality against business-critical benchmarks.
#  • Granular Telemetry: Track token usage, tool latency, and cost-per-run to maintain unit economics and detect
#    anomalies.
#  • Human-in-the-Loop: Implement structured annotation queues for high-risk decisions, ensuring human oversight for
#    irreversible actions.
#
# For example, Block utilizes an "Intelligence Layer" pattern to analyze millions of transactions without exposing
# production systems to direct agentic control, effectively isolating risk while maintaining operational speed.
#
# Sources
#
#  • LLM guardrails: Best practices for deploying LLM apps securely :
#    https://www.datadoghq.com/blog/llm-guardrails-best-practices
#  • AI Security Best Practices: Building a Foundation for Responsible Innovation :
#    https://www.obsidiansecurity.com/blog/ai-security-best-practices
#  • Top 5 AI Agent Observability Best Practices for Building Reliable AI :
#    https://www.getmaxim.ai/articles/ai-agent-evaluation-top-5-lessons-for-building-production-ready-systems-2
#  • What is AI Observability? Monitoring and Troubleshooting Your LLM Infrastructure :
#    https://konghq.com/blog/learning-center/guide-to-ai-observability
#  • The Emerged Security and Privacy of LLM Agent: A Survey with Case Studies : https://arxiv.org/html/2407.19354v2
#  • You don't know what your agent will do until it's in production :
#    https://www.langchain.com/blog/production-monitoring
#  • MCP Best Practices: Architecture & Implementation Guide : https://modelcontextprotocol.info/docs/best-practices
#  • Model Context Protocol — Deep Dive (Part 3.2) :
#    https://abvijaykumar.medium.com/model-context-protocol-deep-dive-part-3-2-3-hands-on-deployment-patterns-3c2c45e
#    65efb
#  • The MCP Implementation Guide: Solving the 7 Failure Modes that Doom AI Architectures :
#    https://natesnewsletter.substack.com/p/the-mcp-implementation-guide-solving
#  • What is Model Context Protocol (MCP)? A guide : https://cloud.google.com/discover/what-is-model-context-protocol
#  • What is the Model Context Protocol (MCP)? : https://www.databricks.com/blog/what-is-model-context-protocol
#  • A Beginner's Guide to Visually Understanding MCP Architecture :
#    https://snyk.io/articles/a-beginners-guide-to-visually-understanding-mcp-architecture
#  • Autonomous AI Agents in Production: A Complete CTO Guide :
#    https://deployflow.co/blog/autonomous-ai-agents-production
#  • Safe and scalable AI infrastructure for autonomous agents :
#    https://invisibletech.ai/blog/infrastructure-to-run-autonomous-ai-agents
#  • Scaling Autonomous AI Agents: Kubernetes, Runtimes, and Architecture Insights :
#    https://www.epsilla.com/blogs/scaling-autonomous-ai-agents-kubernetes-runtimes-architecture
#  • What Infrastructure Do Autonomous AI Agents Actually Need? :
#    https://blog.equinix.com/blog/2026/04/20/what-infrastructure-do-autonomous-ai-agents-actually-need/
#  • Enterprise AI Agent Pilot to Production: A Scaling Framework :
#    https://agility-at-scale.com/ai/agents/pilot-to-production-scaling
#  • Scaling AI Agents in the Enterprise: The Hard Problems and How to Solve Them :
#    https://thenewstack.io/scaling-ai-agents-in-the-enterprise-the-hard-problems-and-how-to-solve-them
#  • AI Agent Observability: Monitoring and Debugging Agent Workflows :
#    https://www.truefoundry.com/blog/ai-agent-observability-tools
#  • Agentic Observability | Fiddler | Documentation : https://docs.fiddler.ai/getting-started/agentic-monitoring
#  • AI Agent Observability: Monitoring Autonomous Systems in Production :
#    https://agentuity.com/ai-agent-observability
#  • AI Observability for LLMs & Agents | MLflow AI Platform : https://mlflow.org/ai-observability
#  • What is agent observability? Tracing tool calls, memory, and multi-step reasoning :
#    https://www.braintrust.dev/articles/agent-observability-tracing-tool-calls-memory
#  • The 2026 Guide to AI Agent Workflows :
#    https://www.vellum.ai/blog/agentic-workflows-emerging-architectures-and-design-patterns
#  • Agentic AI Security: Risks, Defenses & 3 Practical Frameworks :
#    https://www.tigera.io/learn/guides/ai-agent-security/agentic-ai-security
#  • Four security principles for agentic AI systems :
#    https://aws.amazon.com/blogs/security/four-security-principles-for-agentic-ai-systems
#  • How to Prevent Prompt Injection in AI Agents : https://goteleport.com/blog/prevent-prompt-injection
#  • Agentic AI in ODC: are there any built-in defense against prompt injection? :
#    https://www.outsystems.com/forums/discussion/105715/agentic-ai-in-odc-are-there-any-built-in-defense-against-pro
#    mpt-injection
#  • Prompt Injection and the Security Risks of Agentic Coding Tools :
#    https://www.securecodewarrior.com/article/prompt-injection-and-the-security-risks-of-agentic-coding-tools
#  • Agentic AI Security: A Guide to Threats, Risks & Best Practices 2025 :
#    https://www.rippling.com/blog/agentic-ai-security
#
# Conclusion
#
# The transition from static automation to autonomous agentic systems represents a fundamental shift in enterprise
# software architecture. By integrating reasoning, planning, memory, and tool use, organizations can move beyond
# simple text generation toward reliable, multi-step problem solving. However, the non-deterministic nature of these
# systems necessitates a rigorous approach to governance, observability, and architectural design. As demonstrated,
# selecting the appropriate design pattern and orchestration framework is critical to balancing autonomous capability
# with operational safety.
#
#
#  Pattern            Primary Use Case        Key Consideration
#  ──────────────────────────────────────────────────────────────────────────
#  ReAct              Exploratory research    High token consumption
#  Plan-and-Execute   Structured workflows    Reduced latency/cost
#  Reflection         Quality-critical tasks  Increased compute overhead
#  Human-in-the-loop  High-stakes decisions   Essential for safety/governance
#
#
# Moving forward, enterprises should prioritize stateful, graph-based orchestration frameworks like LangGraph to
# ensure auditability. Future efforts must focus on implementing "LLM-as-a-judge" evaluation pipelines and robust
# infrastructure-level guardrails to mitigate the risks inherent in autonomous decision-making.

# %%
print(.)
# Out:
#   Cell In[105], line 1
#     print(.)
#           ^
# SyntaxError: invalid syntax

# %%
topic = "Detailed report on how is NVIDIA winning the game against its competitors"
await call_planner_agent(agent=reporter_agent,
                         prompt=topic)
# Out:
# --- Generating Report Plan ---
# --- Generating Report Plan Completed ---
# --- Generating Search Queries for Section: The CUDA Ecosystem: The Software Moat ---
# --- Generating Search Queries for Section: Full-Stack Vertical Integration ---
# --- Generating Search Queries for Section: Generational Performance Leadership ---
# --- Generating Search Queries for Section: Strategic Partnerships and Ecosystem Expansion ---
# --- Generating Search Queries for Section: Strategic Partnerships and Ecosystem Expansion Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Full-Stack Vertical Integration Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: The CUDA Ecosystem: The Software Moat Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Generational Performance Leadership Completed ---
# --- Searching Web for Queries ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Strategic Partnerships and Ecosystem Expansion ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Full-Stack Vertical Integration ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Generational Performance Leadership ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : The CUDA Ecosystem: The Software Moat ---
# --- Writing Section : Strategic Partnerships and Ecosystem Expansion Completed ---
# --- Writing Section : Full-Stack Vertical Integration Completed ---
# --- Writing Section : Generational Performance Leadership Completed ---
# --- Writing Section : The CUDA Ecosystem: The Software Moat Completed ---
# --- Formatting Completed Sections ---
# --- Formatting Completed Sections is Done ---
# --- Writing Final Section: Introduction ---
# --- Writing Final Section: Conclusion ---
# --- Writing Final Section: Introduction Completed ---
# --- Writing Final Section: Conclusion Completed ---
# --- Compiling Final Report ---
# --- Compiling Final Report Done ---
# ==================================================
# Final Report:
# [{'type': 'text', 'text': '# NVIDIA: Architecting the AI Era\n\nNVIDIA has evolved from a specialized graphics
# hardware provider into the indispensable architect of the modern AI economy. By commanding the data center sector
# through a combination of unmatched software ecosystems, vertically integrated infrastructure, and rapid
# generational innovation, the company has established a dominant market position that is increasingly difficult for
# competitors to challenge.\n\nThis report analyzes the strategic pillars supporting NVIDIA’s market leadership. From
# the foundational software moat of CUDA to the deployment of gigawatt-scale AI factories, we examine how NVIDIA’s
# holistic approach to computing creates a self-reinforcing cycle of adoption, performance, and ecosystem expansion
# that defines the current trajectory of global AI development.', 'extras': {'signature':
# 'EjQKMgEMOdbH5IhvQA0XF9AiW8vECykkqhmKdBN2Zva8zcXSO0NAyobodcQ6tLU9iE+t+UpN'}}]
#
# [{'type': 'text', 'text': '## The CUDA Ecosystem: The Software Moat\n\nNVIDIA’s primary competitive advantage is
# not its hardware, but the CUDA software ecosystem, which functions as a self-reinforcing moat that prevents
# enterprise migration to competing architectures. By providing a comprehensive platform—including compilers,
# optimized libraries like cuDNN and TensorRT, and extensive developer tools—NVIDIA has successfully standardized GPU
# computing. This ecosystem creates high switching costs, as developers become deeply invested in CUDA-specific
# optimizations, kernel fusions, and CI/CD pipelines.\n\n| Metric | NVIDIA CUDA | AMD ROCm |\n| :--- | :--- | :---
# |\n| Maturity | 18+ years (since 2006) | 8+ years (since 2016) |\n| Developer Base | 4M+ registered developers |
# Smaller, growing community |\n| Framework Support | Native, deep integration | Improving, but lags in stability
# |\n\nThe "AlexNet moment" in 2012 solidified CUDA’s dominance, as researchers standardized on NVIDIA hardware for
# deep learning. Today, even when competitors like AMD offer hardware with comparable raw performance, the "fast
# path" for AI development remains CUDA-first. Enterprise adoption relies on the operational stability of the
# software stack, making the vast pool of CUDA-proficient engineers and production-hardened libraries a barrier that
# hardware specifications alone cannot overcome.\n\n### Sources\n- NVIDIA: Harnessing Open Innovation to Promote User
# Lock-in : https://www.europeanbusinessreview.com/nvidia-harnessing-open-innovation-to-promote-user-lock-in\n-
# Nvidia’s CUDA Lock-In and Supply Scarcity Make Its AI Chip Moat Harder to Break Than It Looks :
# https://news.alphastreet.com/nvidias-cuda-lock-in-and-supply-scarcity-make-its-ai-chip-moat-harder-to-break-than-it
# -looks\n- CUDA is Still a Giant Moat for NVIDIA :
# https://weightythoughts.com/p/cuda-is-still-a-giant-moat-for-nvidia', 'extras': {'signature':
# 'EjQKMgEMOdbHrHNLj2DUmf59bNp0oR8g6DeY7tmwczlEtQq0NQSOKJFDXvafPpTJ7+Rc5oN6'}}]
#
# [{'type': 'text', 'text': '## Full-Stack Vertical Integration\n\nNVIDIA achieves superior AI infrastructure
# performance by tightly coupling proprietary hardware, high-speed interconnects, and a comprehensive software stack
# into a unified, vertically integrated ecosystem. Unlike general-purpose IT infrastructure, NVIDIA’s "AI factory"
# approach optimizes the entire data pipeline, from GPU-accelerated compute to the network fabric.\n\nThe foundation
# of this integration is the Blackwell GPU architecture, which utilizes a multi-die design to overcome physical
# manufacturing limits, delivering up to 20 petaFLOPS of AI performance. This hardware is interconnected via
# fifth-generation NVLink and NVSwitch, creating a non-blocking fabric that allows up to 576 GPUs to function as a
# single, massive accelerator. To scale beyond individual racks, NVIDIA integrates Spectrum-X Ethernet or Quantum
# InfiniBand, ensuring low-latency, high-throughput communication.\n\n| Component | Role in Integration |\n| :--- |
# :--- |\n| Blackwell GPU | High-density compute and neural rendering |\n| NVLink/NVSwitch | Intra-rack, low-latency
# GPU communication |\n| Spectrum-X/InfiniBand | Scalable inter-rack data fabric |\n| CUDA/CUDA-X | Software-defined
# hardware abstraction |\n\nA prime example is the GB200 NVL72 system, which acts as a single logical GPU, delivering
# 30x faster inference for trillion-parameter models compared to previous generations, demonstrating the power of
# this integrated, full-stack design.\n\n### Sources\n- NVIDIA RTX Blackwell GPU Architecture :
# https://images.nvidia.com/aem-dam/Solutions/geforce/blackwell/nvidia-rtx-blackwell-gpu-architecture.pdf\n- NVIDIA
# Blackwell Platform Arrives to Power a New Era of Computing :
# https://investor.nvidia.com/news/press-release-details/2024/NVIDIA-Blackwell-Platform-Arrives-to-Power-a-New-Era-of
# -Computing/default.aspx\n- NVIDIA Spectrum-X Ethernet Switches Speed Up Networks for Meta and Oracle :
# https://investor.nvidia.com/news/press-release-details/2025/NVIDIA-Spectrum-X-Ethernet-Switches-Speed-Up-Networks-f
# or-Meta-and-Oracle/default.aspx', 'extras': {'signature':
# 'EjQKMgEMOdbHL/8mL3bISawQ62aPeBU/2sXZwOMmteU3zf+q1RSQ2Aqfs978lqwz58GFRBub'}}]
#
# [{'type': 'text', 'text': '## Generational Performance Leadership\n\nThe NVIDIA Blackwell architecture represents a
# transformative leap in accelerated computing, delivering up to 2.5x the performance of the Hopper generation by
# fundamentally re-engineering memory, interconnect, and precision capabilities. While Hopper (H100/H200) established
# the standard for transformer-based AI with 80 billion transistors and HBM3/HBM3e memory, Blackwell (B200/GB200)
# scales to 208 billion transistors using a dual-die design. This architectural shift enables massive throughput for
# trillion-parameter models.\n\nKey advancements driving this performance gap include:\n\n*   Second-Generation
# Transformer Engine: Native hardware support for FP4 and FP6 precision, doubling effective model size and compute
# throughput.\n*   Fifth-Generation NVLink: Delivers 1.8 TB/s of bidirectional bandwidth per GPU, enabling the GB200
# NVL72 to function as a single, unified 72-GPU accelerator.\n*   Dedicated Decompression Engine: Offloads data
# processing from SMs, accelerating database and analytics pipelines by up to 6x compared to Hopper.\n\nA concrete
# example of this leadership is the GB200 NVL72 cluster, which achieves 30x faster real-time inference for
# trillion-parameter models compared to previous generations. By integrating these innovations, NVIDIA maintains a
# significant performance lead in generative AI and large-scale simulation workloads.\n\n### Sources\n- NVIDIA
# Blackwell vs NVIDIA Hopper: A Detailed Comparison :
# https://www.nexgencloud.com/blog/performance-benchmarks/nvidia-blackwell-vs-nvidia-hopper-a-detailed-comparison\n-
# Blackwell vs Hopper: A Deep Dive GPU Architecture Comparison :
# https://intuitionlabs.ai/articles/blackwell-vs-hopper-gpu-architecture-comparison\n- NVIDIA Rubin vs Blackwell vs
# Hopper - Spheron : https://www.spheron.network/blog/nvidia-rubin-vs-blackwell-vs-hopper\n- Comparing Blackwell vs
# Hopper | B200 & B100 vs H200 & H100 : https://www.exxactcorp.com/blog/hpc/comparing-nvidia-tensor-core-gpus',
# 'extras': {'signature': 'EjQKMgEMOdbH2mukVifv8akSYs7up5+jUhNEH/P6fTJHJ9V4gblF0Cb6tWaLbTj0UEUeeqd1'}}]
#
# [{'type': 'text', 'text': '## Strategic Partnerships and Ecosystem Expansion\n\nNVIDIA has transitioned from a
# component supplier to the primary architect of the global AI power infrastructure, establishing its technology as
# the industry standard for gigawatt-scale AI factories. This strategic shift involves controlling the entire
# infrastructure stack, from grid-to-chip, to ensure facilities can handle the extreme power density of modern GPU
# architectures.\n\nNVIDIA’s ecosystem expansion relies on deep alliances across the value chain:\n\n*   Power
# Infrastructure: Partnerships with ABB, Eaton, and Schneider Electric define new standards for 800 VDC power
# architectures, essential for future 1 MW racks.\n*   Construction and Modularization: Collaborations with firms
# like Bechtel modularize the "AI Factory" blueprint, accelerating construction timelines for gigawatt-scale
# facilities.\n*   Cloud and Sovereign AI: Strategic alliances with hyperscalers like Microsoft and Meta, alongside
# international projects like the \$4.3 billion development in Malaysia, secure global market reach.\n*   Energy
# Integration: Recent collaborations with energy leaders like NextEra Energy and Constellation enable AI factories to
# operate as flexible grid assets, utilizing co-located storage to support grid reliability.\n\nBy integrating these
# diverse partners, NVIDIA creates a competitive moat, ensuring its hardware remains the foundational layer for the
# \$7 trillion data center market.\n\n### Sources\n- NVIDIA’s AI Strategy: Powering the 2025 \$7T Data Center :
# https://enkiai.com/nvidia/nvidias-ai-strategy-powering-the-2025-7t-data-center\n- NVIDIA and Emerald AI Join
# Leading Energy Companies to Pioneer Flexible AI Factories as Grid Assets :
# https://nvidianews.nvidia.com/news/nvidia-and-emerald-ai-join-leading-energy-companies-to-pioneer-flexible-ai-facto
# ries-as-grid-assets', 'extras': {'signature':
# 'EjQKMgEMOdbHuKj1ySkOZy9udTy8MNuWTE/sGE3PKhaIhOo685F3WpERNqRC52ZKzwDtvcca'}}]
#
# [{'type': 'text', 'text': '## Conclusion\n\nNVIDIA’s market dominance is the result of a deliberate, multi-layered
# strategy that transcends mere hardware performance. By anchoring its position in the CUDA software ecosystem,
# NVIDIA has created a formidable barrier to entry that forces developers and enterprises to remain within its orbit.
# This software moat is reinforced by a relentless pace of generational innovation and a full-stack approach that
# treats the entire data center—from power grid to GPU interconnect—as a single, optimized product. As AI workloads
# scale toward trillion-parameter models, NVIDIA’s ability to integrate these disparate elements into a cohesive "AI
# factory" ensures its continued role as the foundational architect of modern computing.\n\n| Pillar of Advantage |
# Strategic Impact |\n| :--- | :--- |\n| CUDA Ecosystem | High switching costs and deep developer lock-in. |\n|
# Vertical Integration | Unified hardware/software stack for maximum efficiency. |\n| Performance Leadership | Rapid
# generational leaps (Hopper to Blackwell). |\n| Ecosystem Expansion | Control over the entire "AI factory" supply
# chain. |\n\nMoving forward, NVIDIA’s success will depend on its ability to maintain this integration as power and
# thermal constraints become the primary bottlenecks for global AI infrastructure.', 'extras': {'signature':
# 'EjQKMgEMOdbHhW0A8jk68JC7sFFGqqmcOmVCZHXh3CWQhSxtE9QdLjk800DEzvdSRHW7jyXb'}}]

# %%
topic = "Detailed report on how DeepSeek has disrupted the AI Market"
await call_planner_agent(agent=reporter_agent,
                         prompt=topic)
# Out:
# --- Generating Report Plan ---
