# %%
## Multimodal agent

# %% [markdown]
# ## Research Agent
#
# ### Create an agent that performs research using the TavilySearch tool. This agent is used to gather the required information.

# %% [markdown]
# ## Chart Generator Agent
# ### Create an agent that generates charts using the PythonREPL tool. This agent is used to create charts.

# %% [markdown]
# ## Multi-Agent Graph

# %%
# =========================
# Imports & Setup
# =========================
import operator
import uuid
import os
from typing import Annotated, Sequence
from typing_extensions import TypedDict

from dotenv import load_dotenv
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_core.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.runnables import RunnableConfig
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.checkpoint.memory import MemorySaver
from langchain_experimental.utilities import PythonREPL

load_dotenv(override=True)

# =========================
# Python REPL Tool
# =========================
python_repl = PythonREPL()

## Tavily Search Tool
# Tavily search tool
tavily_tool = TavilySearchResults(
    max_results=5,
    search_depth="advanced"
)

@tool
def python_repl_tool(
    code: Annotated[str, "Pure python code only. You MUST save charts as image files."]
):
    """
    Executes Python code. Charts MUST be saved to disk and file path printed.
    """
    try:
        result = python_repl.run(code)
    except BaseException as e:
        return f"Execution failed: {repr(e)}"

    return f"Python executed successfully.\n{result}"

# =========================
# LLM Setup (Groq)
# =========================
llm = ChatOpenAI(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY"),
    temperature=0
)

# =========================
# System Prompt Helper
# =========================
def make_system_prompt(suffix: str) -> str:
    return (
        "You are part of a multi-agent system.\n"
        "Follow your role strictly.\n"
        "Do not refuse tasks.\n"
        "Do not explain limitations.\n"
        f"{suffix}"
    )

# =========================
# Research Agent (FORCED DATA)
# =========================
research_agent_system_prompt = """
You are a research agent.

Your job is to gather data needed for chart generation.

STRICT RULES:
1. Use tools like TavilySearch when external data is required.
2. ALWAYS extract or infer numeric values.
3. NEVER refuse due to lack of real-time access.
4. If exact values are unavailable, use best estimates.
5. DO NOT generate charts or code.

OUTPUT FORMAT (MANDATORY):
Return data in a simple, structured, machine-readable format.

Example:
Label: <category or x-axis value>
Value: <numeric value>
Unit: <optional>

Repeat for each data point.
"""



research_agent = create_react_agent(
    llm,
    tools=[tavily_tool],
    prompt=make_system_prompt(research_agent_system_prompt),
)

def research_node(state: MessagesState) -> MessagesState:
    result = research_agent.invoke(state)
    return {"messages": result["messages"]}

# =========================
# Chart Agent (FORCED PYTHONREPL)
# =========================
chart_generator_system_prompt = """
You are a chart-generation agent.

Your job is to generate charts based on structured numeric data
provided by the research agent.

STRICT RULES:
1. You MUST parse numeric values from the previous message.
2. You MUST decide an appropriate chart type (bar, line, pie) unless specified.
3. You MUST use the `python_repl_tool` to execute your code. DO NOT output raw python code in markdown. Use the tool.
4. You MUST save the chart as a PNG file.
5. You MUST print the saved file path.
6. You MUST NOT refuse or explain limitations.
7. You MUST NOT return FINAL ANSWER until AFTER the tool executes.
8. ALWAYS CALL THE TOOL with proper JSON/tool call format. NEVER write Python code without calling the tool.

Charting rules:
- Use matplotlib
- Label axes clearly
- Add a meaningful title
- Use plt.savefig(), NOT plt.show()

After successful execution, respond ONLY with:
FINAL ANSWER
"""


chart_agent = create_react_agent(
    llm,
    tools=[python_repl_tool],
    prompt=make_system_prompt(chart_generator_system_prompt),
)

def chart_node(state: MessagesState) -> MessagesState:
    result = chart_agent.invoke(state)
    return {"messages": result["messages"]}

# =========================
# Router
# =========================
def router(state: MessagesState):
    last_message = state["messages"][-1]
    if "FINAL ANSWER" in last_message.content:
        return END
    return "continue"

# =========================
# Build LangGraph
# =========================
workflow = StateGraph(MessagesState)
workflow.add_node("researcher", research_node)
workflow.add_node("chart_generator", chart_node)

workflow.add_conditional_edges(
    "researcher",
    router,
    {"continue": "chart_generator", END: END},
)
workflow.add_conditional_edges(
    "chart_generator",
    router,
    {"continue": "researcher", END: END},
)

workflow.add_edge(START, "researcher")

app = workflow.compile(checkpointer=MemorySaver())

app
# Out:
# /var/folders/ry/0dp2gqbj4nv8q6qbdj7z67700000gn/T/ipykernel_73300/645847191.py:30: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tavily_tool = TavilySearchResults(
# /var/folders/ry/0dp2gqbj4nv8q6qbdj7z67700000gn/T/ipykernel_73300/645847191.py:99: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   research_agent = create_react_agent(
# /var/folders/ry/0dp2gqbj4nv8q6qbdj7z67700000gn/T/ipykernel_73300/645847191.py:138: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   chart_agent = create_react_agent(

# %%
from langchain_opentutorial.graphs import visualize_graph
visualize_graph(app, xray=True)

# %%
# =========================
# Invoke Graph
# =========================
config = RunnableConfig(
    recursion_limit=10,
    configurable={"thread_id": str(uuid.uuid4())}
)

inputs = {
    "messages": [
        HumanMessage(
            content="can you give me a bar chart for gdps of india, usa, and china for the year 2024"
        )
    ]
}

result = app.invoke(inputs, config=config)
result
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 17
#       4 config = RunnableConfig(
#       5     recursion_limit=10,
#       6     configurable={"thread_id": str(uuid.uuid4())}
#       7 )
#       9 inputs = {
#      10     "messages": [
#      11         HumanMessage(
#    (...)     14     ]
#      15 }
# ---> 17 result = app.invoke(inputs, config=config)
#      18 result
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[1], line 145, in chart_node(state)
#     144 def chart_node(state: MessagesState) -> MessagesState:
# --> 145     result = chart_agent.invoke(state)
#     146     return {"messages": result["messages"]}
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:393, in RunnableCallable.invoke(self, input, config, **kwargs)
#     391     # run in context
#     392     with set_config_context(child_config, run) as context:
# --> 393         ret = context.run(self.func, *args, **kwargs)
#     394 except BaseException as e:
#     395     run_manager.on_chain_error(e)
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langgraph/prebuilt/chat_agent_executor.py:668, in create_react_agent.<locals>.call_model(state, runtime, config)
#     666     response = cast(AIMessage, dynamic_model.invoke(model_input, config))  # type: ignore[arg-type]
#     667 else:
# --> 668     response = cast(AIMessage, static_model.invoke(model_input, config))  # type: ignore[union-attr]
#     670 # add agent name to the AIMessage
#     671 response.name = name
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3151, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3149                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3150             else:
# -> 3151                 input_ = context.run(step.invoke, input_, config)
#    3152 # finish the root run
#    3153 except BaseException as e:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5557, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5550 @override
#    5551 def invoke(
#    5552     self,
#    (...)   5555     **kwargs: Any | None,
#    5556 ) -> Output:
# -> 5557     return self.bound.invoke(
#    5558         input,
#    5559         self._merge_configs(config),
#    5560         **{**self.kwargs, **kwargs},
#    5561     )
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1380, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1378     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1379         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1380     raise e
#    1381 if (
#    1382     self.include_response_headers
#    1383     and raw_response is not None
#    1384     and hasattr(raw_response, "headers")
#    1385 ):
#    1386     generation_info = {"headers": dict(raw_response.headers)}
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1375, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1368         return _construct_lc_result_from_responses_api(
#    1369             response,
#    1370             schema=original_schema_obj,
#    1371             metadata=generation_info,
#    1372             output_version=self.output_version,
#    1373         )
#    1374     else:
# -> 1375         raw_response = self.client.with_raw_response.create(**payload)
#    1376         response = raw_response.parse()
#    1377 except Exception as e:
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': "\n\n\n```python\nimport matplotlib.pyplot as plt\n\n# Data\nlabels = ['India', 'USA', 'China']\n"}}
# During task with name 'agent' and id '806719ed-ac69-0c32-99db-fb5dbcfb125a'
# During task with name 'chart_generator' and id 'fbe8d1ab-4cf6-910c-732e-9f3d30e559e9'

# %% [markdown]
# ## 2nd Example:

# %%
inputs = {
    "messages": [
        HumanMessage(
            content="Compare prices of iPhone 15 on Amazon, Flipkart, Meesho"
        )
    ]
}

result = app.invoke(inputs, config=config)
result
# Out:
# {'messages': [HumanMessage(content='can you give me a bar chart for gdps of india, usa, and china for the year 2024', additional_kwargs={}, response_metadata={}, id='a4c90310-c7a2-4999-8593-fe73918d8159'),
#   AIMessage(content="To provide a bar chart for the GDPs of India, USA, and China for the year 2024, I would need to gather the GDP data for these countries for that specific year. Since I don't have direct access to real-time or future data, I'll use the Tavily search tool to find estimates or projections for the GDPs of India, USA, and China for 2024.\n\nLet's start by searching for the GDP projections for these countries in 2024:\n\n", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 136, 'prompt_tokens': 913, 'total_tokens': 1049, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.054014482, 'prompt_time': 0.025123638, 'completion_time': 0.307375137, 'total_time': 0.332498775}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'id': 'chatcmpl-a8cf8e41-2cba-4893-89de-1bc7964abc5d', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b74c5-a9bc-7202-aa71-a94b5ce66874-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'India USA China GDP projections 2024'}, 'id': 'yfsph2h4p', 'type': 'tool_call'}], usage_metadata={'input_tokens': 913, 'output_tokens': 136, 'total_tokens': 1049, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='[{"title": "World GDP Ranking 2025", "url": "https://statisticstimes.com/economy/projected-world-gdp-ranking.php", "content": "As of 2025, the United States and China will occupy the first two places in both methods\' GDP rankings. The US and China\'s margins are coming down in nominal rankings as China\'s GDP growth rate in 2025 (4.80%) is higher than the US\'s 2.02%. On a nominal basis, the US will be ahead of China by $11.2 trillion in 2025. On a PPP basis, China is ahead of the US by Int. $10.4 trillion, and the gap is increasing. China will remain the world\'s largest economy on a PPP basis over the next few decades, [...] | Country/Economy | GDP (PPP) (billions of Int. $) | Growth (%) | GDP per capita (PPP) (Int. $) | Continent |\\n| 2024 | Rank | 2025 | Rank | Share | diff | 2025 | 2025 | Rank |\\n| China, People\'s Republic of | 38,209.55 | 1 | 41,015.82 | 1 | 19.6 %  4.80 | 29,191 | 79 | Asia |\\n| United States | 29,298.03 | 2 | 30,615.74 | 2 | 14.7 % | 10,400 | 2.02 | 89,599 | 11 | North America |\\n| India | 16,215.93 | 3 | 17,714.19 | 3 | 8.48 % | 12,902 | 6.65 | 12,101 | 127 | Asia | [...] | Country/Economy | GDP (Nominal) (billions of $) | Growth (%) | GDP per capita (Nominal) ($) | Continent |\\n| 2024 | Rank | 2025 | Rank | Share (%) | diff | 2025 | 2025 | Rank |\\n| United States | 29,298.03 | 1 | 30,615.74 | 1 | 26.1  2.02 | 89,599 | 8 | North America |\\n| China, People\'s Republic of | 18,749.76 | 2 | 19,398.58 | 2 | 16.6 | 11,217 | 4.80 | 13,806 | 78 | Asia |\\n| Germany | 4,684.18 | 3 | 5,013.57 | 3 | 4.28 | 14,385 | 0.19 | 59,925 | 19 | Europe |", "score": 0.9997565}, {"title": "India Overtakes California As World\'s Fourth Largest ...", "url": "https://www.newsweek.com/india-overtakes-california-as-worlds-fourth-largest-economy-data-11283382", "content": "India\'s new figures could represent a significant annual jump. India\'s GDP was estimated at $3.9 trillion in 2024 by the International Monetary Fund\'s (IMF) 2024 World Economic Outlook data.\\n\\nIn terms of sovereign nations in 2024, Japan held fourth place ($4.02 trillion), behind Germany ($4.65 trillion), China ($18.74 trillion) and the U.S. ($29.18 trillion), according to the IMF. India placed fifth. [...] India’s economy maintained strong momentum in the second quarter of 2025-26, with real GDP growing 8.2 percent, up from 7.8 percent in the previous quarter and 7.4 percent at the end of 2024-25, according to government data. The growth was powered by resilient domestic demand despite global trade and policy uncertainties. [...] \\"With GDP valued at US$4.18 trillion, India has surpassed Japan to become the world’s fourth-largest economy, and is poised to displace Germany from the third rank in the next two-and-a-half to three years, with projected GDP of US$7.3 trillion by 2030.\\"\\n\\nJapan and California are yet to release GDP estimates for the year. Official confirmation of figures will rely on the IMF\'s final annual GDP figures expected in the first half of 2026.", "score": 0.9992206}, {"title": "India\'s Path To Becoming One of the World\'s Largest ...", "url": "https://econofact.org/indias-path-to-becoming-one-of-the-worlds-largest-economies", "content": "India is now the fastest growing major economy in the world, with a high and rising contribution to global growth. In Purchasing Power Parity (PPP) terms (that is after adjusting for differences in price levels and the cost of living across countries), India accounted for about 8.3 percent of global GDP in 2024 — up from less than 3.5 percent in 1990. It is now the world’s fourth-largest economy — behind only China, the United States, and the European Union. In 2024, India contributed close to", "score": 0.9986853}, {"title": "Largest economies worldwide 2025", "url": "https://www.statista.com/statistics/268173/countries-with-the-largest-gross-domestic-product-gdp/?srsltid=AfmBOoo95JUhTvetSQszYxjK1Vu5BtV7t2R91AiJCqIndCzcgiIZVAPI", "content": "In 2025, the Unite ...
#   AIMessage(content='Label: GDP (Nominal) in trillion USD\nValue: 4.07\nUnit: trillion USD\n\nLabel: GDP (Nominal) in trillion USD\nValue: 18.74\nUnit: trillion USD\n\nLabel: GDP (Nominal) in trillion USD\nValue: 29.29\nUnit: trillion USD\n\nHere are the 2024 GDP Nominal values for India, China, and the USA:\n- India: 4.07 trillion USD\n- China: 18.74 trillion USD\n- USA: 29.29 trillion USD', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 3148, 'total_tokens': 3262, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.049518152, 'prompt_time': 0.095946128, 'completion_time': 0.257261053, 'total_time': 0.353207181}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_79da0e0073', 'id': 'chatcmpl-8fc9bfee-f463-48cd-ba3f-2f9dea9b7327', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b74c5-b56e-79c3-b34c-588b30e02d60-0', usage_metadata={'input_tokens': 3148, 'output_tokens': 114, 'total_tokens': 3262, 'input_token_details': {}, 'output_token_details': {}}),
#   AIMessage(content='\n\nI will now generate a bar chart using these values.\n\n', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 3281, 'total_tokens': 3512, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.163752839, 'prompt_time': 0.10054517, 'completion_time': 0.560084845, 'total_time': 0.660630015}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_79da0e0073', 'id': 'chatcmpl-c2b916fc-5d30-40b2-bb5a-72a8913641e8', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b74c5-b72f-76e1-b5f6-1584d8477b68-0', tool_calls=[{'name': 'python_repl_tool', 'args': {'code': "import matplotlib.pyplot as plt\n\n# Data\ndata = {'Country': ['India', 'China', 'USA'],\n        'GDP (Nominal) in trillion USD': [4.07, 18.74, 29.29]}\n\n# Create DataFrame\ndf = pd.DataFrame(data)\n\n# Create bar plot\nplt.figure(figsize=(10,6))\nplt.bar(df['Country'], df['GDP (Nominal) in trillion USD'], color ='maroon')\nplt.xlabel('Country')\nplt.ylabel('GDP (Nominal) in trillion USD')\nplt.title('GDP (Nominal) in trillion USD for India, China, and USA (2024)')\nplt.xticks(rotation=45)\n\n# Save plot to disk\nplt.tight_layout()\nplt.savefig('gdp_comparison.png')\nprint('gdp_comparison.png')"}, 'id': 'xx38bss9b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3281, 'output_tokens': 231, 'total_tokens': 3512, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='Python executed successfully.\nNameError("name \'pd\' is not defined")', name='python_repl_tool', id='4a25958a-93db-4d0e-ad46-4a1a0dd2f645', tool_call_id='xx38bss9b'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 224, 'prompt_tokens': 3540, 'total_tokens': 3764, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.054349944, 'prompt_time': 0.102680926, 'completion_time': 0.520401082, 'total_time': 0.623082008}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'id': 'chatcmpl-5c14c06a-a0bd-4719-9d51-fcbf1e42b309', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b74c5-babf-70f0-a047-b76bb39f86d3-0', tool_calls=[{'name': 'python_repl_tool', 'args': {'code': "import matplotlib.pyplot as plt\nimport pandas as pd\n\n# Data\ndata = {'Country': ['India', 'China', 'USA'],\n        'GDP (Nominal) in trillion USD': [4.07, 18.74, 29.29]}\n\n# Create DataFrame\ndf = pd.DataFrame(data)\n\n# Create bar plot\nplt.figure(figsize=(10,6))\nplt.bar(df['Country'], df['GDP (Nominal) in trillion USD'], color ='maroon')\nplt.xlabel('Country')\nplt.ylabel('GDP (Nominal) in trillion USD')\nplt.title('GDP (Nominal) in trillion USD for India, China, and USA (2024)')\nplt.xticks(rotation=45)\n\n# Save plot to disk\nplt.tight_layout()\nplt.savefig('gdp_comparison.png')\nprint('gdp_comparison.png')"}, 'id': 'zav2cqjdt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3540, 'output_tokens': 224, 'total_tokens': 3764, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='Python executed successfully.\ngdp_comparison.png\n', name='python_repl_tool', id='f034f7b3-590c-435d-aa56-f85f88b4a230', tool_call_id='zav2cqjdt'),
#   AIMessage(content='FINAL ANSWER', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 3794, 'total_tokens': 3797, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.049544159, 'prompt_time': 0.12165556, 'completion_time': 0.007091121, 'total_time': 0.128746681}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_79da0e0073', 'id': 'chatcmpl-226fe5a9-bc2d-4b19-8b91-8ff019931fab', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b74c5-bdd7-7e53-b06c-357f3c44ce72-0', usage_metadata={'input_tokens': 3794, 'output_tokens': 3, 'total_tokens': 3797, 'input_token_details': {}, 'output_token_details': {}}),
#   HumanMessage(content='Compare prices of iPhone 15 on Amazon, Flipkart, Meesho', additional_kwargs={}, response_metadata={}, id='bb07265d-e855-4263-b22c-bbeef75ead92'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 3802, 'total_tokens': 3846, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.049789161, 'prompt_time': 0.115098178, 'completion_time': 0.099660986, 'total_time': 0.214759164}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'id': 'chatcmpl-95e86326-01e3-4382-87c7-baccc74cc917', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b74c8-53ef-7b80-a9b4-6c1e77885a03-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'iPhone 15 price comparison Amazon Flipkart Meesho'}, 'id': 'cnhpdc1vt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3802, 'output_tokens': 44, 'total_tokens': 3846, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='[{"title": "iPhone 15 best deal on Amazon vs Flipkart: Check price, discount to ...", "url": "https://tech.hindustantimes.com/mobile/news/iphone-15-best-deal-on-amazon-vs-flipkart-check-price-discount-to-get-the-best-offer-71722034856040.html", "content": "## Amazon vs Flipkart Deals- Choose from the best\\n\\nOn Amazon, the iPhone 15 is priced at Rs. 70,900 after an 11% discount, while Flipkart offers it at Rs. 71,999 with a 9% discount. Both platforms have received great ratings for the iPhone 15. Amazon provides no-cost EMI options starting at Rs. 3,437 per month, whereas Flipkart offers no-cost EMI starting at Rs. 12,000 per month.\\n\\nAlso Read: BSNL 4G rollout delayed again, govt-backed telecom player now aims deployment by June 2025 [...] Mobiles Laptops Tablets [...] # iPhone 15 best deal on Amazon vs Flipkart: Check price, discount to get the best offer\\n\\n## Keen too buy a new iPhone 15 and find out where to get the best deals between Amazon and Flipkart. Dive into the details of its innovative design, powerful camera, and efficient performance to make an informed purchase decision.\\n\\nUpdated on:  Jul 27 2024, 11:02 IST\\n\\n### By ANNIE SHARMA", "score": 0.9999502}, {"title": "Apple iPhone 15 On Discount: Amazon Vs Flipkart Price Comparison", "url": "https://www.ndtvprofit.com/technology/apple-iphone-15-256gb-discount-alert-amazon-vs-flipkart-price-comparison", "content": "Amazon is currently offering three colour variants of the iPhone 15 (256GB) — blue, black and pink — at Rs 69,500, marking a 13% discount on the original price. Buyers save a substantial Rs 10,400 benefit, compared to the official MRP. The green and yellow variants are priced slightly higher, listed at Rs 70,400.\\n\\nAdditional savings can be unlocked through various bank debit and credit card offers, which further reduce the final price. [...] ## The iPhone 15 (256GB) is now available at a significantly reduced price, with Amazon and Flipkart both offering good deals.\\n\\n NDTV Profit Tech\\n\\n02 Jun 2025, 10:40 AM IST i\\n\\nSave\\n\\nFlipkart is offering the iPhone 15 (256GB) across all five colour variants at a flat price of Rs 74,900, which translates to a 6% discount on the MRP.\\n\\n(Photo source: Apple)\\n\\nShowQuick Read\\n\\nSummary is AI Generated. Newsroom Reviewed [...] Flipkart is offering the iPhone 15 (256GB) across all five colour variants at a flat price of Rs 74,900, which translates to a 6% discount on the MRP.\\n\\nLike Amazon, Flipkart too provides bank-related discounts and exchange offers, though the actual benefit from the trade-in programme will vary based on the condition of the old phone.\\n\\n## Specifications Of The iPhone 15", "score": 0.9999039}, {"title": "iPhones Big Price Drop! Flipkart GOAT Sale & Amazon Prime ...", "url": "https://www.youtube.com/watch?v=37msDfbLYog", "content": "फोंस परचेस करने चाहिए या फिर नहीं किसकी अच्छी प्राइसिंग है। तो पहले बात करते हैं Amazon पे। इस पे iPhone 15 लिस्टेड है जिसकी प्राइिंग है 57249 आफ्टर ऑल द ऑफर्स। मतलब यहां पे बेसिकली लीस्ट प्राइसिंग बताई गई है आफ्टर कार्ड ऑफर। अब ऑब्वियसली यह कोई बहुत ज्यादा धांसू प्राइिंग नहीं है। इतनी प्राइिंग में एग्जैक्टली iPhone 15 पहले भी Amazon की सेल में आ चुका है। बाकी Amazon पे एक और iPhone लिस्टेड है जो है iPhone 16E। इसकी नॉर्मल प्राइिंग है ₹50,000 एंड आफ्टर कार डिस्काउंट अराउंड ₹49,249। अब देखो [...] है iPhone 16 की। बाकी तो इसके अलावा बहुत सारे और iPhonस भी लिस्टेड हैं iPhone 13 14 Pro सीरीज तो iPhone 13 की प्राइसिंग ₹43249 वहीं iPhone 14 की प्राइसिंग ₹49,000 सो टोटली अवॉयड देम यह प्राइजिंग बिल्कुल भी अच्छी नहीं है। आप खुद ही सोच के देखो जिस प्राइिंग पे आपको अभी iPhone 14 मिल रहा है। इससे भी कम प्राइसिंग में आपको 2 महीने के बाद iPhone 15 मिल जाएगा। तो कोई भी सेंस नहीं है इस प्राइिंग पे इन iPhonस को परचेस करने का। अब iPhone 16 Pro की प्राइिंग मेंशन कर रखी है ₹99,900 बट यह भी एक्सचेंज बोनस [...] # iPhones Big Price Drop! 😍🔥 Flipkart GOAT Sale & Amazon Prime Day Sale 2025 (HINDI)\\n## GadgetsLife\\n350000 subs ...
#   AIMessage(content="The current prices of the iPhone 15 on various platforms are:\n\n* Amazon: ₹47,999 (a flat discount of ₹11,901 from its official MRP of ₹59,900) for the 128GB model in Black, with additional bank discounts and exchange offers available.\n* Flipkart: ₹59,900, with a 13% discount and additional bank discounts and exchange offers available.\n\nMeesho's prices are unavailable as it wasn't present in search results.\n\nPlease note that prices may vary depending on the seller, storage capacity, and condition of the device.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 119, 'prompt_tokens': 5716, 'total_tokens': 5835, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.050283293, 'prompt_time': 0.166061506, 'completion_time': 0.269366835, 'total_time': 0.435428341}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'id': 'chatcmpl-d900bae4-c39b-4838-8f22-c114210aae94', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b74c8-6667-71b3-b6ba-688f02694efc-0', usage_metadata={'input_tokens': 5716, 'output_tokens': 119, 'total_tokens': 5835, 'input_token_details': {}, 'output_token_details': {}}),
#   AIMessage(content=" It's always a good idea to check the prices on multiple platforms and compare them before making a purchase.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 5854, 'total_tokens': 5875, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.05060069, 'prompt_time': 0.162718789, 'completion_time': 0.050168439, 'total_time': 0.212887228}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'id': 'chatcmpl-e52a9eaf-3c7f-4ec8-a36d-125823842ec6', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b74c8-68cd-72c2-8c01-dcafc385f964-0', usage_metadata={'input_tokens': 5854, 'output_tokens': 21, 'total_tokens': 5875, 'input_token_details': {}, 'output_token_details': {}}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1, 'prompt_tokens': 5859, 'total_tokens': 5860, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'prompt_time': 0.171067718, 'completion_time': 0.002570262, 'total_time': 0.17363798}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_79da0e0073', 'id': 'chatcmpl-d0a8012d-c7bc-40cc-a7c1-1937d9355a04', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b74c8-6a66-76d2-afe3-71bd909a3330-0', usage_metadata={'input_tokens': 5859, 'output_tokens': 1, 'total_tokens': 5860, 'input_token_details': {}, 'output_token_details': {}}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 204, 'prompt_tokens': 5884, 'total_tokens': 6088, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.227310509, 'prompt_time': 0.175775619, 'completion_time': 0.471121848, 'total_time': 0.646897467}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_79da0e0073', 'id': 'chatcmpl-513e247c-61cf-45b2-a69b-0f82fd819dda', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b74c8-6bb6-7c82-85d4-758746906410-0', tool_calls=[{'name': 'python_repl_tool', 'args': {'code': "import matplotlib.pyplot as plt\nimport pandas as pd\n\n# Data\ndata = {'Platform': ['Amazon', 'Flipkart', 'Meesho'],\n        'Price (₹)': [47999, 59900, 0]}\n\n# Create DataFrame\ndf = pd.DataFrame(data)\n\n# Create bar plot\nplt.figure(figsize=(10,6))\nplt.bar(df['Platform'], df['Price (₹)'], color ='maroon')\nplt.xlabel('Platform')\nplt.ylabel('Price (₹)')\nplt.title('iPhone 15 Price Comparison')\nplt.xticks(rotation=45)\n\n# Save plot to disk\nplt.tight_layout()\nplt.savefig('iphone15_price_comparison.png')\nprint('iphone15_price_comparison.png')"}, 'id': 'zfxx5zt04', 'type': 'tool_call'}], usage_metadata={'input_tokens': 5884, 'output_tokens': 204, 'total_tokens': 6088, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='Python executed successfully.\niphone15_price_comparison.png\n', name='python_repl_tool', id='a7354495-dc48-487e-b879-945fad744cfc', tool_call_id='zfxx5zt04'),
#   AIMessage(content='FINAL ANSWER', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 6124, 'total_tokens': 6127, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.050406996, 'prompt_time': 0.170229743, 'completion_time': 0.007688592, 'total_time': 0.177918335}, 'model_provider': 'openai', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'id': 'chatcmpl-5ac98180-25fa-4ec1-8b9b-b6aa16dd9f30', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b74c8-6fd7-7173-91cf-cb01347f5631-0', usage_metadata={'input_tokens': 6124, 'output_tokens': 3, 'total_tokens': 6127, 'input_token_details': {}, 'output_token_details': {}})]}
